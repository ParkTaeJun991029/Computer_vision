# %% [markdown]
# ### MMDetection 설치
# * 강의 영상에는 pip install mmcv-full로 mmcv를 설치(약 10분 정도의 시간이 소요)
# * 실습코드는 pip install mmcv-full -f https://download.openmmlab.com/mmcv/dist/cu116/torch1.13/index.html 로 변경(설치에 12초 정도 걸림. 2022.09).
# * 코랩의 pytorch 버전이 2.0으로 upgrade되었으나 mmdetection은 아직 pytorch 2.0을 지원하지 않기에 pytorch 1.13으로 downgrade 필요(2023.04월에 코랩 pytorch upgrade)
# *  2023년 4월 6일 기준으로 mmdetection이 3.0으로 upgrade됨. 실습 코드는 mmdetection 2.x 기준으므로 mmdetection 2.x 소스코드 설치 필요.

# %%
#코랩의 pytorch 버전이 2.0으로 upgrade됨.
import torch
print(torch.__version__)
# Out:
# 2.0.1+cu118

# %%
#현재 mmdetection이 pytorch 2.x를 지원하지 않음. pytorch 1.13+ CUDA 116 환경으로 코랩 커널 downgrade
# downgrade 설치시 ERROR: pip's dependency resolver... 부분은 신경쓰지 않아도 됨.
# !pip install torch==1.13.0+cu116 torchvision==0.14.0+cu116 --extra-index-url https://download.pytorch.org/whl/cu116
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://download.pytorch.org/whl/cu116
# Collecting torch==1.13.0+cu116
#   Downloading https://download.pytorch.org/whl/cu116/torch-1.13.0%2Bcu116-cp310-cp310-linux_x86_64.whl (1983.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 GB 890.9 kB/s eta 0:00:00
# Collecting torchvision==0.14.0+cu116
#   Downloading https://download.pytorch.org/whl/cu116/torchvision-0.14.0%2Bcu116-cp310-cp310-linux_x86_64.whl (24.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 31.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.13.0+cu116) (4.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14.0+cu116) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14.0+cu116) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14.0+cu116) (8.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.0+cu116) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.0+cu116) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.0+cu116) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.0+cu116) (3.4)
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.2+cu118
#     Uninstalling torchvision-0.15.2+cu118:
#       Successfully uninstalled torchvision-0.15.2+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 1.13.0+cu116 which is incompatible.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 1.13.0+cu116 which is incompatible.
# torchtext 0.15.2 requires torch==2.0.1, but you have torch 1.13.0+cu116 which is incompatible.
# Successfully installed torch-1.13.0+cu116 torchvision-0.14.0+cu116

# %%
# mmcv를 위해서 mmcv-full을 먼저 설치해야 함. https://mmcv.readthedocs.io/en/latest/get_started/installation.html 설치 과정 참조.
# !pip install mmcv-full -f https://download.openmmlab.com/mmcv/dist/cu116/torch1.13/index.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu116/torch1.13/index.html
# Collecting mmcv-full
#   Downloading https://download.openmmlab.com/mmcv/dist/cu116/torch1.13.0/mmcv_full-1.7.1-cp310-cp310-manylinux1_x86_64.whl (46.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 MB 8.4 MB/s eta 0:00:00
# Collecting addict (from mmcv-full)
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmcv-full) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mmcv-full) (23.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from mmcv-full) (8.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from mmcv-full) (6.0)
# Collecting yapf (from mmcv-full)
#   Downloading yapf-0.40.0-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 18.9 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.10/dist-packages (from mmcv-full) (4.7.0.72)
# Collecting importlib-metadata>=6.6.0 (from yapf->mmcv-full)
#   Downloading importlib_metadata-6.6.0-py3-none-any.whl (22 kB)
# Collecting platformdirs>=3.5.1 (from yapf->mmcv-full)
#   Downloading platformdirs-3.5.3-py3-none-any.whl (15 kB)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv-full) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->mmcv-full) (3.15.0)
# Installing collected packages: addict, platformdirs, importlib-metadata, yapf, mmcv-full
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 3.3.0
#     Uninstalling platformdirs-3.3.0:
#       Successfully uninstalled platformdirs-3.3.0
# Successfully installed addict-2.4.0 importlib-metadata-6.6.0 mmcv-full-1.7.1 platformdirs-3.5.3 yapf-0.40.0

# %%
# 2023년 4월 6일 기준으로 mmdetection이 3.0으로 upgrade됨. 실습 코드는 mmdetection 2.x 기준임.
# mmdetection 2.x branch의 소스코드 기반으로 mmdetection 설치 필요.
# !git clone --branch 2.x https://github.com/open-mmlab/mmdetection.git
# !cd mmdetection; python setup.py install
# Out:
# Cloning into 'mmdetection'...
# remote: Enumerating objects: 36644, done.
# remote: Counting objects: 100% (1295/1295), done.
# remote: Compressing objects: 100% (727/727), done.
# remote: Total 36644 (delta 732), reused 938 (delta 554), pack-reused 35349
# Receiving objects: 100% (36644/36644), 56.86 MiB | 18.22 MiB/s, done.
# Resolving deltas: 100% (25667/25667), done.
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating mmdet.egg-info
# writing mmdet.egg-info/PKG-INFO
# writing dependency_links to mmdet.egg-info/dependency_links.txt
# writing requirements to mmdet.egg-info/requires.txt
# writing top-level names to mmdet.egg-info/top_level.txt
# writing manifest file 'mmdet.egg-info/SOURCES.txt'
# reading manifest file 'mmdet.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'mmdet/VERSION'
# warning: no files found matching 'mmdet/.mim/model-index.yml'
# warning: no files found matching 'mmdet/.mim/demo/*/*'
# warning: no files found matching '*.py' under directory 'mmdet/.mim/configs'
# warning: no files found matching '*.yml' under directory 'mmdet/.mim/configs'
# warning: no files found matching '*.sh' under directory 'mmdet/.mim/tools'
# warning: no files found matching '*.py' under directory 'mmdet/.mim/tools'
# adding license file 'LICENSE'
# writing manifest file 'mmdet.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/mmdet
# copying mmdet/__init__.py -> build/lib/mmdet
# copying mmdet/version.py -> build/lib/mmdet
# creating build/lib/mmdet/utils
# copying mmdet/utils/split_batch.py -> build/lib/mmdet/utils
# copying mmdet/utils/profiling.py -> build/lib/mmdet/utils
# copying mmdet/utils/setup_env.py -> build/lib/mmdet/utils
# copying mmdet/utils/collect_env.py -> build/lib/mmdet/utils
# copying mmdet/utils/util_distribution.py -> build/lib/mmdet/utils
# copying mmdet/utils/contextmanagers.py -> build/lib/mmdet/utils
# copying mmdet/utils/rfnext.py -> build/lib/mmdet/utils
# copying mmdet/utils/util_random.py -> build/lib/mmdet/utils
# copying mmdet/utils/util_mixins.py -> build/lib/mmdet/utils
# copying mmdet/utils/__init__.py -> build/lib/mmdet/utils
# copying mmdet/utils/logger.py -> build/lib/mmdet/utils
# copying mmdet/utils/misc.py -> build/lib/mmdet/utils
# copying mmdet/utils/compat_config.py -> build/lib/mmdet/utils
# copying mmdet/utils/memory.py -> build/lib/mmdet/utils
# copying mmdet/utils/replace_cfg_vals.py -> build/lib/mmdet/utils
# copying mmdet/utils/ascend_util.py -> build/lib/mmdet/utils
# creating build/lib/mmdet/apis
# copying mmdet/apis/inference.py -> build/lib/mmdet/apis
# copying mmdet/apis/train.py -> build/lib/mmdet/apis
# copying mmdet/apis/test.py -> build/lib/mmdet/apis
# copying mmdet/apis/__init__.py -> build/lib/mmdet/apis
# creating build/lib/mmdet/datasets
# copying mmdet/datasets/wider_face.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/coco.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/voc.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/builder.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/utils.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/cityscapes.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/custom.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/objects365.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/coco_panoptic.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/xml_style.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/coco_occluded.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/openimages.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/__init__.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/lvis.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/dataset_wrappers.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/deepfashion.py -> build/lib/mmdet/datasets
# creating build/lib/mmdet/models
# copying mmdet/models/builder.py -> build/lib/mmdet/models
# copying mmdet/models/__init__.py -> build/lib/mmdet/models
# creating build/lib/mmdet/core
# copying mmdet/core/__init__.py -> build/lib/mmdet/core
# creating build/lib/mmdet/datasets/api_wrappers
# copying mmdet/datasets/api_wrappers/panoptic_evaluation.py -> build/lib/mmdet/datasets/api_wrappers
# copying mmdet/datasets/api_wrappers/__init__.py -> build/lib/mmdet/datasets/api_wrappers
# copying mmdet/datasets/api_wrappers/coco_api.py -> build/lib/mmdet/datasets/api_wrappers
# creating build/lib/mmdet/datasets/samplers
# copying mmdet/datasets/samplers/distributed_sampler.py -> build/lib/mmdet/datasets/samplers
# copying mmdet/datasets/samplers/class_aware_sampler.py -> build/lib/mmdet/datasets/samplers
# copying mmdet/datasets/samplers/group_sampler.py -> build/lib/mmdet/datasets/samplers
# copying mmdet/datasets/samplers/__init__.py -> build/lib/mmdet/datasets/samplers
# copying mmdet/datasets/samplers/infinite_sampler.py -> build/lib/mmdet/datasets/samplers
# creating build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/formating.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/instaboost.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/compose.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/test_time_aug.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/auto_augment.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/transforms.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/__init__.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/loading.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/formatting.py -> build/lib/mmdet/datasets/pipelines
# creating build/lib/mmdet/models/utils
# copying mmdet/models/utils/gaussian_target.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/positional_encoding.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/res_layer.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/inverted_residual.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/brick_wrappers.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/point_sample.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/panoptic_gt_processing.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/conv_upsample.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/builder.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/make_divisible.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/transformer.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/__init__.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/normed_predictor.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/se_layer.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/ckpt_convert.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/misc.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/csp_layer.py -> build/lib/mmdet/models/utils
# creating build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/trident_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/standard_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/htc_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/cascade_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/double_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/base_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/scnet_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/test_mixins.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/pisa_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/dynamic_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/point_rend_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/__init__.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/grid_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/sparse_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/mask_scoring_roi_head.py -> build/lib/mmdet/models/roi_heads
# creating build/lib/mmdet/models/plugins
# copying mmdet/models/plugins/msdeformattn_pixel_decoder.py -> build/lib/mmdet/models/plugins
# copying mmdet/models/plugins/dropblock.py -> build/lib/mmdet/models/plugins
# copying mmdet/models/plugins/__init__.py -> build/lib/mmdet/models/plugins
# copying mmdet/models/plugins/pixel_decoder.py -> build/lib/mmdet/models/plugins
# creating build/lib/mmdet/models/losses
# copying mmdet/models/losses/pisa_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/gaussian_focal_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/varifocal_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/seesaw_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/utils.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/dice_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/iou_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/smooth_l1_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/kd_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/cross_entropy_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/balanced_l1_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/accuracy.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/ghm_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/__init__.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/focal_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/gfocal_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/ae_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/mse_loss.py -> build/lib/mmdet/models/losses
# creating build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/scnet.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/lad.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/nasfcos.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/grid_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/kd_one_stage.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/paa.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/retinanet.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/yolact.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/ddod.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/trident_faster_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/solov2.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/maskformer.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/single_stage.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/fcos.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/cornernet.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/rpn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/yolo.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/base.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/sparse_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/two_stage.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/atss.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/fast_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/point_rend.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/cascade_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/single_stage_instance_seg.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/panoptic_two_stage_segmentor.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/mask2former.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/htc.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/mask_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/mask_scoring_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/solo.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/faster_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/__init__.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/yolox.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/centernet.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/reppoints_detector.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/detr.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/deformable_detr.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/fovea.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/panoptic_fpn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/tood.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/vfnet.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/queryinst.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/gfl.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/yolof.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/autoassign.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/fsaf.py -> build/lib/mmdet/models/detectors
# creating build/lib/mmdet/models/seg_heads
# copying mmdet/models/seg_heads/panoptic_fpn_head.py -> build/lib/mmdet/models/seg_heads
# copying mmdet/models/seg_heads/__init__.py -> build/lib/mmdet/models/seg_heads
# copying mmdet/models/seg_heads/base_semantic_head.py -> build/lib/mmdet/models/seg_heads
# creating build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/pisa_retinanet_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ddod_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ascend_anchor_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/rpn_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ga_retina_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/yolof_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/mask2former_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/fovea_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/lad_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/sabl_retina_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ascend_retina_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ssd_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/detr_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/fcos_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/cascade_rpn_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/fsaf_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/corner_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/atss_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/anchor_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ld_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/gfl_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/yolo_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/nasfcos_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/embedding_rpn_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/dense_test_mixins.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/maskformer_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/pisa_ssd_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/deformable_detr_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/base_mask_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/yolox_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/reppoints_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ascend_ssd_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/anchor_free_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/vfnet_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/free_anchor_retina_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/__init__.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/base_dense_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/retina_sepbn_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/centernet_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/centripetal_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ga_rpn_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/autoassign_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/solo_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/guided_anchor_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/tood_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/retina_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/paa_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/solov2_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/yolact_head.py -> build/lib/mmdet/models/dense_heads
# creating build/lib/mmdet/models/necks
# copying mmdet/models/necks/bfp.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/dyhead.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/hrfpn.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/dilated_encoder.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/rfp.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/channel_mapper.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/nasfcos_fpn.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/fpn_carafe.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/ct_resnet_neck.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/yolox_pafpn.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/fpn.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/__init__.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/yolo_neck.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/pafpn.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/nas_fpn.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/fpg.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/ssd_neck.py -> build/lib/mmdet/models/necks
# creating build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/regnet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/resnext.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/mobilenet_v2.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/efficientnet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/pvt.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/ssd_vgg.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/detectors_resnet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/res2net.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/csp_darknet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/trident_resnet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/darknet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/detectors_resnext.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/__init__.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/resnet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/swin.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/hourglass.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/hrnet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/resnest.py -> build/lib/mmdet/models/backbones
# creating build/lib/mmdet/models/roi_heads/shared_heads
# copying mmdet/models/roi_heads/shared_heads/res_layer.py -> build/lib/mmdet/models/roi_heads/shared_heads
# copying mmdet/models/roi_heads/shared_heads/__init__.py -> build/lib/mmdet/models/roi_heads/shared_heads
# creating build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/grid_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/fused_semantic_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/feature_relay_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/scnet_mask_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/global_context_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/fcn_mask_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/maskiou_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/__init__.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/coarse_mask_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/dynamic_mask_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/scnet_semantic_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/mask_point_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/htc_mask_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# creating build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/bbox_head.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/convfc_bbox_head.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/dii_head.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/scnet_bbox_head.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/__init__.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/sabl_head.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/double_bbox_head.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# creating build/lib/mmdet/models/roi_heads/roi_extractors
# copying mmdet/models/roi_heads/roi_extractors/generic_roi_extractor.py -> build/lib/mmdet/models/roi_heads/roi_extractors
# copying mmdet/models/roi_heads/roi_extractors/base_roi_extractor.py -> build/lib/mmdet/models/roi_heads/roi_extractors
# copying mmdet/models/roi_heads/roi_extractors/__init__.py -> build/lib/mmdet/models/roi_heads/roi_extractors
# copying mmdet/models/roi_heads/roi_extractors/single_level_roi_extractor.py -> build/lib/mmdet/models/roi_heads/roi_extractors
# creating build/lib/mmdet/models/seg_heads/panoptic_fusion_heads
# copying mmdet/models/seg_heads/panoptic_fusion_heads/base_panoptic_fusion_head.py -> build/lib/mmdet/models/seg_heads/panoptic_fusion_heads
# copying mmdet/models/seg_heads/panoptic_fusion_heads/__init__.py -> build/lib/mmdet/models/seg_heads/panoptic_fusion_heads
# copying mmdet/models/seg_heads/panoptic_fusion_heads/maskformer_fusion_head.py -> build/lib/mmdet/models/seg_heads/panoptic_fusion_heads
# copying mmdet/models/seg_heads/panoptic_fusion_heads/heuristic_fusion_head.py -> build/lib/mmdet/models/seg_heads/panoptic_fusion_heads
# creating build/lib/mmdet/core/utils
# copying mmdet/core/utils/dist_utils.py -> build/lib/mmdet/core/utils
# copying mmdet/core/utils/__init__.py -> build/lib/mmdet/core/utils
# copying mmdet/core/utils/misc.py -> build/lib/mmdet/core/utils
# creating build/lib/mmdet/core/data_structures
# copying mmdet/core/data_structures/general_data.py -> build/lib/mmdet/core/data_structures
# copying mmdet/core/data_structures/instance_data.py -> build/lib/mmdet/core/data_structures
# copying mmdet/core/data_structures/__init__.py -> build/lib/mmdet/core/data_structures
# creating build/lib/mmdet/core/post_processing
# copying mmdet/core/post_processing/merge_augs.py -> build/lib/mmdet/core/post_processing
# copying mmdet/core/post_processing/__init__.py -> build/lib/mmdet/core/post_processing
# copying mmdet/core/post_processing/bbox_nms.py -> build/lib/mmdet/core/post_processing
# copying mmdet/core/post_processing/matrix_nms.py -> build/lib/mmdet/core/post_processing
# creating build/lib/mmdet/core/export
# copying mmdet/core/export/pytorch2onnx.py -> build/lib/mmdet/core/export
# copying mmdet/core/export/model_wrappers.py -> build/lib/mmdet/core/export
# copying mmdet/core/export/__init__.py -> build/lib/mmdet/core/export
# copying mmdet/core/export/onnx_helper.py -> build/lib/mmdet/core/export
# creating build/lib/mmdet/core/optimizers
# copying mmdet/core/optimizers/layer_decay_optimizer_constructor.py -> build/lib/mmdet/core/optimizers
# copying mmdet/core/optimizers/builder.py -> build/lib/mmdet/core/optimizers
# copying mmdet/core/optimizers/__init__.py -> build/lib/mmdet/core/optimizers
# creating build/lib/mmdet/core/mask
# copying mmdet/core/mask/utils.py -> build/lib/mmdet/core/mask
# copying mmdet/core/mask/mask_target.py -> build/lib/mmdet/core/mask
# copying mmdet/core/mask/structures.py -> build/lib/mmdet/core/mask
# copying mmdet/core/mask/__init__.py -> build/lib/mmdet/core/mask
# creating build/lib/mmdet/core/hook
# copying mmdet/core/hook/sync_random_size_hook.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/yolox_mode_switch_hook.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/wandblogger_hook.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/yolox_lrupdater_hook.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/set_epoch_info_hook.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/checkloss_hook.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/sync_norm_hook.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/__init__.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/ema.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/memory_profiler_hook.py -> build/lib/mmdet/core/hook
# creating build/lib/mmdet/core/visualization
# copying mmdet/core/visualization/image.py -> build/lib/mmdet/core/visualization
# copying mmdet/core/visualization/__init__.py -> build/lib/mmdet/core/visualization
# copying mmdet/core/visualization/palette.py -> build/lib/mmdet/core/visualization
# creating build/lib/mmdet/core/anchor
# copying mmdet/core/anchor/anchor_generator.py -> build/lib/mmdet/core/anchor
# copying mmdet/core/anchor/builder.py -> build/lib/mmdet/core/anchor
# copying mmdet/core/anchor/utils.py -> build/lib/mmdet/core/anchor
# copying mmdet/core/anchor/point_generator.py -> build/lib/mmdet/core/anchor
# copying mmdet/core/anchor/__init__.py -> build/lib/mmdet/core/anchor
# creating build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/bbox_overlaps.py -> build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/mean_ap.py -> build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/recall.py -> build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/eval_hooks.py -> build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/__init__.py -> build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/class_names.py -> build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/panoptic_utils.py -> build/lib/mmdet/core/evaluation
# creating build/lib/mmdet/core/bbox
# copying mmdet/core/bbox/builder.py -> build/lib/mmdet/core/bbox
# copying mmdet/core/bbox/transforms.py -> build/lib/mmdet/core/bbox
# copying mmdet/core/bbox/demodata.py -> build/lib/mmdet/core/bbox
# copying mmdet/core/bbox/__init__.py -> build/lib/mmdet/core/bbox
# creating build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/ascend_max_iou_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/mask_hungarian_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/grid_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/region_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/sim_ota_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/base_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/max_iou_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/ascend_assign_result.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/uniform_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/task_aligned_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/hungarian_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/point_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/__init__.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/center_region_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/assign_result.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/approx_max_iou_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/atss_assigner.py -> build/lib/mmdet/core/bbox/assigners
# creating build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/base_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/bucketing_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/tblr_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/distance_point_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/legacy_delta_xywh_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/yolo_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/delta_xywh_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/__init__.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/pseudo_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# creating build/lib/mmdet/core/bbox/match_costs
# copying mmdet/core/bbox/match_costs/match_cost.py -> build/lib/mmdet/core/bbox/match_costs
# copying mmdet/core/bbox/match_costs/builder.py -> build/lib/mmdet/core/bbox/match_costs
# copying mmdet/core/bbox/match_costs/__init__.py -> build/lib/mmdet/core/bbox/match_costs
# creating build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/random_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/pseudo_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/score_hlr_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/mask_sampling_result.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/iou_balanced_neg_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/base_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/sampling_result.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/instance_balanced_pos_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/combined_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/__init__.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/mask_pseudo_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/ohem_sampler.py -> build/lib/mmdet/core/bbox/samplers
# creating build/lib/mmdet/core/bbox/iou_calculators
# copying mmdet/core/bbox/iou_calculators/builder.py -> build/lib/mmdet/core/bbox/iou_calculators
# copying mmdet/core/bbox/iou_calculators/__init__.py -> build/lib/mmdet/core/bbox/iou_calculators
# copying mmdet/core/bbox/iou_calculators/iou2d_calculator.py -> build/lib/mmdet/core/bbox/iou_calculators
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/mmdet
# creating build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/split_batch.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/profiling.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/setup_env.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/collect_env.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/util_distribution.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/contextmanagers.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/rfnext.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/util_random.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/util_mixins.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/logger.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/misc.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/compat_config.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/memory.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/replace_cfg_vals.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/ascend_util.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# creating build/bdist.linux-x86_64/egg/mmdet/apis
# copying build/lib/mmdet/apis/inference.py -> build/bdist.linux-x86_64/egg/mmdet/apis
# copying build/lib/mmdet/apis/train.py -> build/bdist.linux-x86_64/egg/mmdet/apis
# copying build/lib/mmdet/apis/test.py -> build/bdist.linux-x86_64/egg/mmdet/apis
# copying build/lib/mmdet/apis/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/apis
# creating build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/wider_face.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/coco.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/voc.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/builder.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# creating build/bdist.linux-x86_64/egg/mmdet/datasets/api_wrappers
# copying build/lib/mmdet/datasets/api_wrappers/panoptic_evaluation.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/api_wrappers
# copying build/lib/mmdet/datasets/api_wrappers/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/api_wrappers
# copying build/lib/mmdet/datasets/api_wrappers/coco_api.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/api_wrappers
# copying build/lib/mmdet/datasets/utils.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# creating build/bdist.linux-x86_64/egg/mmdet/datasets/samplers
# copying build/lib/mmdet/datasets/samplers/distributed_sampler.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/samplers
# copying build/lib/mmdet/datasets/samplers/class_aware_sampler.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/samplers
# copying build/lib/mmdet/datasets/samplers/group_sampler.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/samplers
# copying build/lib/mmdet/datasets/samplers/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/samplers
# copying build/lib/mmdet/datasets/samplers/infinite_sampler.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/samplers
# copying build/lib/mmdet/datasets/cityscapes.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/custom.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# creating build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/pipelines/formating.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/pipelines/instaboost.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/pipelines/compose.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/pipelines/test_time_aug.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/pipelines/auto_augment.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/pipelines/transforms.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/pipelines/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/pipelines/loading.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/pipelines/formatting.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/objects365.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/coco_panoptic.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/xml_style.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/coco_occluded.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/openimages.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/lvis.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/dataset_wrappers.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/deepfashion.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# creating build/bdist.linux-x86_64/egg/mmdet/models
# creating build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/gaussian_target.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/positional_encoding.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/res_layer.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/inverted_residual.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/brick_wrappers.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/point_sample.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/panoptic_gt_processing.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/conv_upsample.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/builder.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/make_divisible.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/transformer.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/normed_predictor.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/se_layer.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/ckpt_convert.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/misc.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/csp_layer.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# creating build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/trident_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/standard_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# creating build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/shared_heads
# copying build/lib/mmdet/models/roi_heads/shared_heads/res_layer.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/shared_heads
# copying build/lib/mmdet/models/roi_heads/shared_heads/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/shared_heads
# copying build/lib/mmdet/models/roi_heads/htc_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/cascade_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# creating build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/grid_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/fused_semantic_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/feature_relay_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/scnet_mask_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/global_context_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/fcn_mask_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/maskiou_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/coarse_mask_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/dynamic_mask_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/scnet_semantic_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/mask_point_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/htc_mask_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/double_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/base_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/scnet_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/test_mixins.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# creating build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/bbox_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/convfc_bbox_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/dii_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/scnet_bbox_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/sabl_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/double_bbox_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/pisa_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/dynamic_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/point_rend_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# creating build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/roi_extractors
# copying build/lib/mmdet/models/roi_heads/roi_extractors/generic_roi_extractor.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/roi_extractors
# copying build/lib/mmdet/models/roi_heads/roi_extractors/base_roi_extractor.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/roi_extractors
# copying build/lib/mmdet/models/roi_heads/roi_extractors/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/roi_extractors
# copying build/lib/mmdet/models/roi_heads/roi_extractors/single_level_roi_extractor.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/roi_extractors
# copying build/lib/mmdet/models/roi_heads/grid_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/sparse_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/mask_scoring_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# creating build/bdist.linux-x86_64/egg/mmdet/models/plugins
# copying build/lib/mmdet/models/plugins/msdeformattn_pixel_decoder.py -> build/bdist.linux-x86_64/egg/mmdet/models/plugins
# ...
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/models/backbones/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/models/backbones/resnet.py to resnet.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/models/backbones/swin.py to swin.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/models/backbones/hourglass.py to hourglass.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/models/backbones/hrnet.py to hrnet.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/models/backbones/resnest.py to resnest.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/utils/dist_utils.py to dist_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/utils/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/utils/misc.py to misc.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/data_structures/general_data.py to general_data.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/data_structures/instance_data.py to instance_data.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/data_structures/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/post_processing/merge_augs.py to merge_augs.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/post_processing/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/post_processing/bbox_nms.py to bbox_nms.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/post_processing/matrix_nms.py to matrix_nms.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/export/pytorch2onnx.py to pytorch2onnx.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/export/model_wrappers.py to model_wrappers.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/export/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/export/onnx_helper.py to onnx_helper.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/optimizers/layer_decay_optimizer_constructor.py to layer_decay_optimizer_constructor.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/optimizers/builder.py to builder.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/optimizers/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/mask/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/mask/mask_target.py to mask_target.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/mask/structures.py to structures.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/mask/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/sync_random_size_hook.py to sync_random_size_hook.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/yolox_mode_switch_hook.py to yolox_mode_switch_hook.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/wandblogger_hook.py to wandblogger_hook.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/yolox_lrupdater_hook.py to yolox_lrupdater_hook.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/set_epoch_info_hook.py to set_epoch_info_hook.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/checkloss_hook.py to checkloss_hook.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/sync_norm_hook.py to sync_norm_hook.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/ema.py to ema.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/memory_profiler_hook.py to memory_profiler_hook.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/visualization/image.py to image.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/visualization/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/visualization/palette.py to palette.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/anchor_generator.py to anchor_generator.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/builder.py to builder.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/point_generator.py to point_generator.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/bbox_overlaps.py to bbox_overlaps.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/mean_ap.py to mean_ap.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/recall.py to recall.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/eval_hooks.py to eval_hooks.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/class_names.py to class_names.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/panoptic_utils.py to panoptic_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/ascend_max_iou_assigner.py to ascend_max_iou_assigner.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/mask_hungarian_assigner.py to mask_hungarian_assigner.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/grid_assigner.py to grid_assigner.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/region_assigner.py to region_assigner.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/sim_ota_assigner.py to sim_ota_assigner.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/base_assigner.py to base_assigner.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/max_iou_assigner.py to max_iou_assigner.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/ascend_assign_result.py to ascend_assign_result.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/uniform_assigner.py to uniform_assigner.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/task_aligned_assigner.py to task_aligned_assigner.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/hungarian_assigner.py to hungarian_assigner.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/point_assigner.py to point_assigner.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/center_region_assigner.py to center_region_assigner.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/assign_result.py to assign_result.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/approx_max_iou_assigner.py to approx_max_iou_assigner.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/atss_assigner.py to atss_assigner.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/base_bbox_coder.py to base_bbox_coder.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/bucketing_bbox_coder.py to bucketing_bbox_coder.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/tblr_bbox_coder.py to tblr_bbox_coder.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/distance_point_bbox_coder.py to distance_point_bbox_coder.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/legacy_delta_xywh_bbox_coder.py to legacy_delta_xywh_bbox_coder.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/yolo_bbox_coder.py to yolo_bbox_coder.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/delta_xywh_bbox_coder.py to delta_xywh_bbox_coder.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/pseudo_bbox_coder.py to pseudo_bbox_coder.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/builder.py to builder.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/match_costs/match_cost.py to match_cost.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/match_costs/builder.py to builder.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/match_costs/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/random_sampler.py to random_sampler.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/pseudo_sampler.py to pseudo_sampler.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/score_hlr_sampler.py to score_hlr_sampler.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/mask_sampling_result.py to mask_sampling_result.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/iou_balanced_neg_sampler.py to iou_balanced_neg_sampler.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/base_sampler.py to base_sampler.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/sampling_result.py to sampling_result.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/instance_balanced_pos_sampler.py to instance_balanced_pos_sampler.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/combined_sampler.py to combined_sampler.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/mask_pseudo_sampler.py to mask_pseudo_sampler.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/ohem_sampler.py to ohem_sampler.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/iou_calculators/builder.py to builder.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/iou_calculators/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/iou_calculators/iou2d_calculator.py to iou2d_calculator.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/transforms.py to transforms.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/demodata.py to demodata.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/version.py to version.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating dist
# creating 'dist/mmdet-2.28.2-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing mmdet-2.28.2-py3.10.egg
# creating /usr/local/lib/python3.10/dist-packages/mmdet-2.28.2-py3.10.egg
# Extracting mmdet-2.28.2-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# Adding mmdet 2.28.2 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/mmdet-2.28.2-py3.10.egg
# Processing dependencies for mmdet==2.28.2
# Searching for terminaltables
# Reading https://pypi.org/simple/terminaltables/
# Downloading https://files.pythonhosted.org/packages/c4/fb/ea621e0a19733e01fe4005d46087d383693c0f4a8f824b47d8d4122c87e0/terminaltables-3.1.10-py2.py3-none-any.whl#sha256=e4fdc4179c9e4aab5f674d80f09d76fa436b96fdc698a8505e0a36bf0804a874
# Best match: terminaltables 3.1.10
# Processing terminaltables-3.1.10-py2.py3-none-any.whl
# Installing terminaltables-3.1.10-py2.py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding terminaltables 3.1.10 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/terminaltables-3.1.10-py3.10.egg
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for scipy==1.10.1
# Best match: scipy 1.10.1
# Adding scipy 1.10.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pycocotools==2.0.6
# Best match: pycocotools 2.0.6
# Adding pycocotools 2.0.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for numpy==1.22.4
# Best match: numpy 1.22.4
# Adding numpy 1.22.4 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.10 script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for matplotlib==3.7.1
# Best match: matplotlib 3.7.1
# Adding matplotlib 3.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pyparsing==3.0.9
# Best match: pyparsing 3.0.9
# Adding pyparsing 3.0.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for Pillow==8.4.0
# Best match: Pillow 8.4.0
# Adding Pillow 8.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for packaging==23.1
# Best match: packaging 23.1
# Adding packaging 23.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for kiwisolver==1.4.4
# Best match: kiwisolver 1.4.4
# Adding kiwisolver 1.4.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for fonttools==4.39.3
# Best match: fonttools 4.39.3
# Adding fonttools 4.39.3 to easy-install.pth file
# Installing fonttools script to /usr/local/bin
# Installing pyftmerge script to /usr/local/bin
# Installing pyftsubset script to /usr/local/bin
# Installing ttx script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for cycler==0.11.0
# Best match: cycler 0.11.0
# Adding cycler 0.11.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for contourpy==1.0.7
# Best match: contourpy 1.0.7
# Adding contourpy 1.0.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Finished processing dependencies for mmdet==2.28.2

# %%
# 런타임->런타임 다시 시작 후 아래 수행.
from mmdet.apis import init_detector, inference_detector
import mmcv
import torch
# Out:
# /usr/local/lib/python3.10/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(

# %% [markdown]
# ### Oxford Pet Dataset 다운로드
# image와 annotations을 압축파일로 각각 download 수행.

# %%
# !wget https://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# !wget https://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz
# Out:
# --2023-06-14 06:25:27--  https://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/~vgg/data/pets/images.tar.gz [following]
# --2023-06-14 06:25:28--  https://thor.robots.ox.ac.uk/~vgg/data/pets/images.tar.gz
# Resolving thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)... 129.67.95.98
# Connecting to thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)|129.67.95.98|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/datasets/pets/images.tar.gz [following]
# --2023-06-14 06:25:29--  https://thor.robots.ox.ac.uk/datasets/pets/images.tar.gz
# Reusing existing connection to thor.robots.ox.ac.uk:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 791918971 (755M) [application/octet-stream]
# Saving to: ‘images.tar.gz’
#
# images.tar.gz       100%[===================>] 755.23M  14.5MB/s    in 55s
#
# 2023-06-14 06:26:25 (13.8 MB/s) - ‘images.tar.gz’ saved [791918971/791918971]
#
# --2023-06-14 06:26:25--  https://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/~vgg/data/pets/annotations.tar.gz [following]
# --2023-06-14 06:26:26--  https://thor.robots.ox.ac.uk/~vgg/data/pets/annotations.tar.gz
# Resolving thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)... 129.67.95.98
# Connecting to thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)|129.67.95.98|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/datasets/pets/annotations.tar.gz [following]
# --2023-06-14 06:26:28--  https://thor.robots.ox.ac.uk/datasets/pets/annotations.tar.gz
# Reusing existing connection to thor.robots.ox.ac.uk:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19173078 (18M) [application/octet-stream]
# Saving to: ‘annotations.tar.gz’
#
# annotations.tar.gz  100%[===================>]  18.28M  7.38MB/s    in 2.5s
#
# 2023-06-14 06:26:30 (7.38 MB/s) - ‘annotations.tar.gz’ saved [19173078/19173078]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# /content/data 디렉토리를 만들고 해당 디렉토리에 다운로드 받은 압축 파일 풀기.
# !mkdir /content/data
# !tar -xvf images.tar.gz -C /content/data
# !tar -xvf annotations.tar.gz -C /content/data
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# annotations/trimaps/pug_106.png
# annotations/trimaps/._pug_107.png
# annotations/trimaps/pug_107.png
# annotations/trimaps/._pug_108.png
# annotations/trimaps/pug_108.png
# annotations/trimaps/._pug_109.png
# annotations/trimaps/pug_109.png
# annotations/trimaps/._pug_11.png
# annotations/trimaps/pug_11.png
# annotations/trimaps/._pug_110.png
# annotations/trimaps/pug_110.png
# annotations/trimaps/._pug_111.png
# annotations/trimaps/pug_111.png
# annotations/trimaps/._pug_112.png
# annotations/trimaps/pug_112.png
# annotations/trimaps/._pug_114.png
# annotations/trimaps/pug_114.png
# annotations/trimaps/._pug_115.png
# annotations/trimaps/pug_115.png
# annotations/trimaps/._pug_116.png
# annotations/trimaps/pug_116.png
# annotations/trimaps/._pug_117.png
# annotations/trimaps/pug_117.png
# annotations/trimaps/._pug_118.png
# annotations/trimaps/pug_118.png
# annotations/trimaps/._pug_119.png
# annotations/trimaps/pug_119.png
# annotations/trimaps/._pug_12.png
# annotations/trimaps/pug_12.png
# annotations/trimaps/._pug_120.png
# annotations/trimaps/pug_120.png
# annotations/trimaps/._pug_121.png
# annotations/trimaps/pug_121.png
# annotations/trimaps/._pug_122.png
# annotations/trimaps/pug_122.png
# annotations/trimaps/._pug_123.png
# annotations/trimaps/pug_123.png
# annotations/trimaps/._pug_124.png
# annotations/trimaps/pug_124.png
# annotations/trimaps/._pug_125.png
# annotations/trimaps/pug_125.png
# annotations/trimaps/._pug_126.png
# annotations/trimaps/pug_126.png
# annotations/trimaps/._pug_127.png
# annotations/trimaps/pug_127.png
# annotations/trimaps/._pug_128.png
# annotations/trimaps/pug_128.png
# annotations/trimaps/._pug_129.png
# annotations/trimaps/pug_129.png
# annotations/trimaps/._pug_13.png
# annotations/trimaps/pug_13.png
# annotations/trimaps/._pug_130.png
# annotations/trimaps/pug_130.png
# annotations/trimaps/._pug_131.png
# annotations/trimaps/pug_131.png
# annotations/trimaps/._pug_132.png
# annotations/trimaps/pug_132.png
# annotations/trimaps/._pug_133.png
# annotations/trimaps/pug_133.png
# annotations/trimaps/._pug_134.png
# annotations/trimaps/pug_134.png
# annotations/trimaps/._pug_135.png
# annotations/trimaps/pug_135.png
# annotations/trimaps/._pug_136.png
# annotations/trimaps/pug_136.png
# annotations/trimaps/._pug_137.png
# annotations/trimaps/pug_137.png
# annotations/trimaps/._pug_138.png
# annotations/trimaps/pug_138.png
# annotations/trimaps/._pug_139.png
# annotations/trimaps/pug_139.png
# annotations/trimaps/._pug_14.png
# annotations/trimaps/pug_14.png
# annotations/trimaps/._pug_140.png
# annotations/trimaps/pug_140.png
# annotations/trimaps/._pug_141.png
# annotations/trimaps/pug_141.png
# annotations/trimaps/._pug_142.png
# annotations/trimaps/pug_142.png
# annotations/trimaps/._pug_143.png
# annotations/trimaps/pug_143.png
# annotations/trimaps/._pug_144.png
# annotations/trimaps/pug_144.png
# annotations/trimaps/._pug_145.png
# annotations/trimaps/pug_145.png
# annotations/trimaps/._pug_146.png
# annotations/trimaps/pug_146.png
# annotations/trimaps/._pug_147.png
# annotations/trimaps/pug_147.png
# annotations/trimaps/._pug_148.png
# annotations/trimaps/pug_148.png
# annotations/trimaps/._pug_149.png
# annotations/trimaps/pug_149.png
# annotations/trimaps/._pug_15.png
# annotations/trimaps/pug_15.png
# annotations/trimaps/._pug_150.png
# annotations/trimaps/pug_150.png
# annotations/trimaps/._pug_151.png
# annotations/trimaps/pug_151.png
# annotations/trimaps/._pug_153.png
# annotations/trimaps/pug_153.png
# annotations/trimaps/._pug_154.png
# annotations/trimaps/pug_154.png
# annotations/trimaps/._pug_155.png
# annotations/trimaps/pug_155.png
# annotations/trimaps/._pug_156.png
# annotations/trimaps/pug_156.png
# annotations/trimaps/._pug_157.png
# annotations/trimaps/pug_157.png
# annotations/trimaps/._pug_158.png
# annotations/trimaps/pug_158.png
# annotations/trimaps/._pug_159.png
# annotations/trimaps/pug_159.png
# annotations/trimaps/._pug_16.png
# annotations/trimaps/pug_16.png
# annotations/trimaps/._pug_160.png
# annotations/trimaps/pug_160.png
# annotations/trimaps/._pug_161.png
# annotations/trimaps/pug_161.png
# annotations/trimaps/._pug_162.png
# annotations/trimaps/pug_162.png
# annotations/trimaps/._pug_163.png
# annotations/trimaps/pug_163.png
# annotations/trimaps/._pug_164.png
# annotations/trimaps/pug_164.png
# annotations/trimaps/._pug_165.png
# annotations/trimaps/pug_165.png
# annotations/trimaps/._pug_166.png
# annotations/trimaps/pug_166.png
# annotations/trimaps/._pug_167.png
# annotations/trimaps/pug_167.png
# annotations/trimaps/._pug_168.png
# annotations/trimaps/pug_168.png
# annotations/trimaps/._pug_169.png
# annotations/trimaps/pug_169.png
# annotations/trimaps/._pug_17.png
# annotations/trimaps/pug_17.png
# annotations/trimaps/._pug_170.png
# annotations/trimaps/pug_170.png
# annotations/trimaps/._pug_171.png
# annotations/trimaps/pug_171.png
# annotations/trimaps/._pug_172.png
# annotations/trimaps/pug_172.png
# annotations/trimaps/._pug_173.png
# annotations/trimaps/pug_173.png
# annotations/trimaps/._pug_174.png
# annotations/trimaps/pug_174.png
# annotations/trimaps/._pug_175.png
# annotations/trimaps/pug_175.png
# annotations/trimaps/._pug_176.png
# annotations/trimaps/pug_176.png
# annotations/trimaps/._pug_177.png
# annotations/trimaps/pug_177.png
# annotations/trimaps/._pug_178.png
# annotations/trimaps/pug_178.png
# annotations/trimaps/._pug_179.png
# annotations/trimaps/pug_179.png
# annotations/trimaps/._pug_18.png
# annotations/trimaps/pug_18.png
# annotations/trimaps/._pug_180.png
# annotations/trimaps/pug_180.png
# annotations/trimaps/._pug_181.png
# annotations/trimaps/pug_181.png
# annotations/trimaps/._pug_182.png
# annotations/trimaps/pug_182.png
# annotations/trimaps/._pug_183.png
# annotations/trimaps/pug_183.png
# annotations/trimaps/._pug_184.png
# annotations/trimaps/pug_184.png
# annotations/trimaps/._pug_185.png
# annotations/trimaps/pug_185.png
# annotations/trimaps/._pug_186.png
# annotations/trimaps/pug_186.png
# annotations/trimaps/._pug_187.png
# annotations/trimaps/pug_187.png
# annotations/trimaps/._pug_188.png
# annotations/trimaps/pug_188.png
# annotations/trimaps/._pug_189.png
# annotations/trimaps/pug_189.png
# annotations/trimaps/._pug_19.png
# annotations/trimaps/pug_19.png
# annotations/trimaps/._pug_190.png
# annotations/trimaps/pug_190.png
# annotations/trimaps/._pug_191.png
# annotations/trimaps/pug_191.png
# annotations/trimaps/._pug_192.png
# annotations/trimaps/pug_192.png
# annotations/trimaps/._pug_193.png
# annotations/trimaps/pug_193.png
# annotations/trimaps/._pug_194.png
# annotations/trimaps/pug_194.png
# annotations/trimaps/._pug_195.png
# annotations/trimaps/pug_195.png
# annotations/trimaps/._pug_196.png
# annotations/trimaps/pug_196.png
# annotations/trimaps/._pug_197.png
# annotations/trimaps/pug_197.png
# annotations/trimaps/._pug_198.png
# annotations/trimaps/pug_198.png
# annotations/trimaps/._pug_199.png
# annotations/trimaps/pug_199.png
# annotations/trimaps/._pug_2.png
# annotations/trimaps/pug_2.png
# annotations/trimaps/._pug_20.png
# annotations/trimaps/pug_20.png
# annotations/trimaps/._pug_200.png
# annotations/trimaps/pug_200.png
# annotations/trimaps/._pug_201.png
# annotations/trimaps/pug_201.png
# annotations/trimaps/._pug_202.png
# annotations/trimaps/pug_202.png
# annotations/trimaps/._pug_203.png
# annotations/trimaps/pug_203.png
# annotations/trimaps/._pug_21.png
# annotations/trimaps/pug_21.png
# annotations/trimaps/._pug_22.png
# annotations/trimaps/pug_22.png
# annotations/trimaps/._pug_23.png
# annotations/trimaps/pug_23.png
# annotations/trimaps/._pug_24.png
# annotations/trimaps/pug_24.png
# annotations/trimaps/._pug_25.png
# annotations/trimaps/pug_25.png
# annotations/trimaps/._pug_26.png
# annotations/trimaps/pug_26.png
# annotations/trimaps/._pug_27.png
# annotations/trimaps/pug_27.png
# annotations/trimaps/._pug_28.png
# annotations/trimaps/pug_28.png
# annotations/trimaps/._pug_29.png
# annotations/trimaps/pug_29.png
# annotations/trimaps/._pug_3.png
# annotations/trimaps/pug_3.png
# annotations/trimaps/._pug_30.png
# annotations/trimaps/pug_30.png
# annotations/trimaps/._pug_31.png
# annotations/trimaps/pug_31.png
# annotations/trimaps/._pug_32.png
# annotations/trimaps/pug_32.png
# annotations/trimaps/._pug_33.png
# annotations/trimaps/pug_33.png
# annotations/trimaps/._pug_34.png
# annotations/trimaps/pug_34.png
# annotations/trimaps/._pug_35.png
# annotations/trimaps/pug_35.png
# annotations/trimaps/._pug_36.png
# annotations/trimaps/pug_36.png
# annotations/trimaps/._pug_37.png
# annotations/trimaps/pug_37.png
# annotations/trimaps/._pug_38.png
# annotations/trimaps/pug_38.png
# annotations/trimaps/._pug_39.png
# annotations/trimaps/pug_39.png
# annotations/trimaps/._pug_4.png
# annotations/trimaps/pug_4.png
# annotations/trimaps/._pug_40.png
# annotations/trimaps/pug_40.png
# annotations/trimaps/._pug_41.png
# annotations/trimaps/pug_41.png
# annotations/trimaps/._pug_42.png
# annotations/trimaps/pug_42.png
# annotations/trimaps/._pug_43.png
# annotations/trimaps/pug_43.png
# annotations/trimaps/._pug_44.png
# annotations/trimaps/pug_44.png
# annotations/trimaps/._pug_45.png
# annotations/trimaps/pug_45.png
# annotations/trimaps/._pug_46.png
# annotations/trimaps/pug_46.png
# annotations/trimaps/._pug_47.png
# annotations/trimaps/pug_47.png
# annotations/trimaps/._pug_48.png
# annotations/trimaps/pug_48.png
# annotations/trimaps/._pug_49.png
# annotations/trimaps/pug_49.png
# annotations/trimaps/._pug_5.png
# annotations/trimaps/pug_5.png
# annotations/trimaps/._pug_50.png
# annotations/trimaps/pug_50.png
# annotations/trimaps/._pug_51.png
# annotations/trimaps/pug_51.png
# annotations/trimaps/._pug_52.png
# annotations/trimaps/pug_52.png
# annotations/trimaps/._pug_53.png
# annotations/trimaps/pug_53.png
# annotations/trimaps/._pug_54.png
# annotations/trimaps/pug_54.png
# annotations/trimaps/._pug_55.png
# annotations/trimaps/pug_55.png
# annotations/trimaps/._pug_56.png
# annotations/trimaps/pug_56.png
# annotations/trimaps/._pug_57.png
# annotations/trimaps/pug_57.png
# annotations/trimaps/._pug_58.png
# annotations/trimaps/pug_58.png
# annotations/trimaps/._pug_59.png
# annotations/trimaps/pug_59.png
# annotations/trimaps/._pug_6.png
# annotations/trimaps/pug_6.png
# annotations/trimaps/._pug_60.png
# annotations/trimaps/pug_60.png
# annotations/trimaps/._pug_61.png
# annotations/trimaps/pug_61.png
# annotations/trimaps/._pug_62.png
# annotations/trimaps/pug_62.png
# annotations/trimaps/._pug_63.png
# annotations/trimaps/pug_63.png
# annotations/trimaps/._pug_64.png
# annotations/trimaps/pug_64.png
# annotations/trimaps/._pug_65.png
# annotations/trimaps/pug_65.png
# annotations/trimaps/._pug_66.png
# annotations/trimaps/pug_66.png
# annotations/trimaps/._pug_67.png
# annotations/trimaps/pug_67.png
# annotations/trimaps/._pug_68.png
# annotations/trimaps/pug_68.png
# annotations/trimaps/._pug_69.png
# annotations/trimaps/pug_69.png
# annotations/trimaps/._pug_7.png
# annotations/trimaps/pug_7.png
# annotations/trimaps/._pug_70.png
# annotations/trimaps/pug_70.png
# annotations/trimaps/._pug_71.png
# annotations/trimaps/pug_71.png
# annotations/trimaps/._pug_72.png
# annotations/trimaps/pug_72.png
# annotations/trimaps/._pug_73.png
# annotations/trimaps/pug_73.png
# annotations/trimaps/._pug_74.png
# annotations/trimaps/pug_74.png
# annotations/trimaps/._pug_75.png
# annotations/trimaps/pug_75.png
# annotations/trimaps/._pug_76.png
# annotations/trimaps/pug_76.png
# annotations/trimaps/._pug_77.png
# annotations/trimaps/pug_77.png
# annotations/trimaps/._pug_78.png
# annotations/trimaps/pug_78.png
# annotations/trimaps/._pug_79.png
# annotations/trimaps/pug_79.png
# annotations/trimaps/._pug_8.png
# annotations/trimaps/pug_8.png
# annotations/trimaps/._pug_80.png
# annotations/trimaps/pug_80.png
# annotations/trimaps/._pug_81.png
# annotations/trimaps/pug_81.png
# annotations/trimaps/._pug_82.png
# annotations/trimaps/pug_82.png
# annotations/trimaps/._pug_84.png
# annotations/trimaps/pug_84.png
# annotations/trimaps/._pug_85.png
# annotations/trimaps/pug_85.png
# annotations/trimaps/._pug_86.png
# annotations/trimaps/pug_86.png
# annotations/trimaps/._pug_87.png
# annotations/trimaps/pug_87.png
# annotations/trimaps/._pug_88.png
# annotations/trimaps/pug_88.png
# annotations/trimaps/._pug_89.png
# annotations/trimaps/pug_89.png
# annotations/trimaps/._pug_9.png
# annotations/trimaps/pug_9.png
# annotations/trimaps/._pug_90.png
# annotations/trimaps/pug_90.png
# annotations/trimaps/._pug_91.png
# annotations/trimaps/pug_91.png
# annotations/trimaps/._pug_92.png
# annotations/trimaps/pug_92.png
# annotations/trimaps/._pug_93.png
# annotations/trimaps/pug_93.png
# annotations/trimaps/._pug_94.png
# annotations/trimaps/pug_94.png
# annotations/trimaps/._pug_95.png
# annotations/trimaps/pug_95.png
# annotations/trimaps/._pug_96.png
# annotations/trimaps/pug_96.png
# annotations/trimaps/._pug_97.png
# annotations/trimaps/pug_97.png
# annotations/trimaps/._pug_98.png
# annotations/trimaps/pug_98.png
# annotations/trimaps/._pug_99.png
# annotations/trimaps/pug_99.png
# annotations/trimaps/._Ragdoll_1.png
# annotations/trimaps/Ragdoll_1.png
# annotations/trimaps/._Ragdoll_10.png
# annotations/trimaps/Ragdoll_10.png
# annotations/trimaps/._Ragdoll_100.png
# annotations/trimaps/Ragdoll_100.png
# annotations/trimaps/._Ragdoll_101.png
# annotations/trimaps/Ragdoll_101.png
# annotations/trimaps/._Ragdoll_103.png
# annotations/trimaps/Ragdoll_103.png
# annotations/trimaps/._Ragdoll_104.png
# annotations/trimaps/Ragdoll_104.png
# annotations/trimaps/._Ragdoll_105.png
# annotations/trimaps/Ragdoll_105.png
# annotations/trimaps/._Ragdoll_106.png
# annotations/trimaps/Ragdoll_106.png
# annotations/trimaps/._Ragdoll_107.png
# annotations/trimaps/Ragdoll_107.png
# annotations/trimaps/._Ragdoll_110.png
# annotations/trimaps/Ragdoll_110.png
# annotations/trimaps/._Ragdoll_111.png
# annotations/trimaps/Ragdoll_111.png
# annotations/trimaps/._Ragdoll_112.png
# annotations/trimaps/Ragdoll_112.png
# annotations/trimaps/._Ragdoll_113.png
# annotations/trimaps/Ragdoll_113.png
# annotations/trimaps/._Ragdoll_114.png
# annotations/trimaps/Ragdoll_114.png
# annotations/trimaps/._Ragdoll_115.png
# annotations/trimaps/Ragdoll_115.png
# annotations/trimaps/._Ragdoll_116.png
# annotations/trimaps/Ragdoll_116.png
# annotations/trimaps/._Ragdoll_117.png
# annotations/trimaps/Ragdoll_117.png
# annotations/trimaps/._Ragdoll_118.png
# annotations/trimaps/Ragdoll_118.png
# annotations/trimaps/._Ragdoll_119.png
# annotations/trimaps/Ragdoll_119.png
# annotations/trimaps/._Ragdoll_12.png
# annotations/trimaps/Ragdoll_12.png
# annotations/trimaps/._Ragdoll_121.png
# annotations/trimaps/Ragdoll_121.png
# annotations/trimaps/._Ragdoll_122.png
# annotations/trimaps/Ragdoll_122.png
# annotations/trimaps/._Ragdoll_124.png
# annotations/trimaps/Ragdoll_124.png
# annotations/trimaps/._Ragdoll_125.png
# annotations/trimaps/._Russian_Blue_101.png
# annotations/trimaps/Russian_Blue_101.png
# annotations/trimaps/._Russian_Blue_102.png
# annotations/trimaps/Russian_Blue_102.png
# annotations/trimaps/._Russian_Blue_103.png
# annotations/trimaps/Russian_Blue_103.png
# annotations/trimaps/._Russian_Blue_104.png
# annotations/trimaps/Russian_Blue_104.png
# annotations/trimaps/._Russian_Blue_106.png
# annotations/trimaps/Russian_Blue_106.png
# annotations/trimaps/._Russian_Blue_107.png
# annotations/trimaps/Russian_Blue_107.png
# annotations/trimaps/._Russian_Blue_108.png
# annotations/trimaps/Russian_Blue_108.png
# annotations/trimaps/._Russian_Blue_109.png
# annotations/trimaps/Russian_Blue_109.png
# annotations/trimaps/._Russian_Blue_110.png
# annotations/trimaps/Russian_Blue_110.png
# annotations/trimaps/._Russian_Blue_111.png
# annotations/trimaps/Russian_Blue_111.png
# annotations/trimaps/._Russian_Blue_112.png
# annotations/trimaps/Russian_Blue_112.png
# annotations/trimaps/._Russian_Blue_113.png
# annotations/trimaps/Russian_Blue_113.png
# annotations/trimaps/._Russian_Blue_114.png
# annotations/trimaps/Russian_Blue_114.png
# annotations/trimaps/._Russian_Blue_115.png
# annotations/trimaps/Russian_Blue_115.png
# annotations/trimaps/._Russian_Blue_116.png
# annotations/trimaps/Russian_Blue_116.png
# annotations/trimaps/._Russian_Blue_117.png
# annotations/trimaps/Russian_Blue_117.png
# annotations/trimaps/._Russian_Blue_118.png
# annotations/trimaps/Russian_Blue_118.png
# annotations/trimaps/._Russian_Blue_119.png
# annotations/trimaps/Russian_Blue_119.png
# annotations/trimaps/._Russian_Blue_12.png
# annotations/trimaps/Russian_Blue_12.png
# annotations/trimaps/._Russian_Blue_120.png
# annotations/trimaps/Russian_Blue_120.png
# annotations/trimaps/._Russian_Blue_122.png
# annotations/trimaps/Russian_Blue_122.png
# annotations/trimaps/._Russian_Blue_123.png
# annotations/trimaps/Russian_Blue_123.png
# annotations/trimaps/._Russian_Blue_124.png
# annotations/trimaps/Russian_Blue_124.png
# annotations/trimaps/._Russian_Blue_125.png
# annotations/trimaps/Russian_Blue_125.png
# annotations/trimaps/._Russian_Blue_127.png
# annotations/trimaps/Russian_Blue_127.png
# annotations/trimaps/._Russian_Blue_128.png
# annotations/trimaps/Russian_Blue_128.png
# annotations/trimaps/._Russian_Blue_129.png
# annotations/trimaps/Russian_Blue_129.png
# annotations/trimaps/._Russian_Blue_13.png
# annotations/trimaps/Russian_Blue_13.png
# annotations/trimaps/._Russian_Blue_130.png
# annotations/trimaps/Russian_Blue_130.png
# annotations/trimaps/._Russian_Blue_131.png
# annotations/trimaps/Russian_Blue_131.png
# annotations/trimaps/._Russian_Blue_132.png
# annotations/trimaps/Russian_Blue_132.png
# annotations/trimaps/._Russian_Blue_133.png
# annotations/trimaps/Russian_Blue_133.png
# annotations/trimaps/._Russian_Blue_135.png
# annotations/trimaps/Russian_Blue_135.png
# annotations/trimaps/._Russian_Blue_136.png
# annotations/trimaps/Russian_Blue_136.png
# annotations/trimaps/._Russian_Blue_137.png
# annotations/trimaps/Russian_Blue_172.png
# annotations/trimaps/._Russian_Blue_173.png
# annotations/trimaps/Russian_Blue_173.png
# annotations/trimaps/._Russian_Blue_174.png
# annotations/trimaps/Russian_Blue_174.png
# annotations/trimaps/._Russian_Blue_175.png
# annotations/trimaps/Russian_Blue_175.png
# annotations/trimaps/._Russian_Blue_176.png
# annotations/trimaps/Russian_Blue_176.png
# annotations/trimaps/._Russian_Blue_177.png
# annotations/trimaps/Russian_Blue_177.png
# annotations/trimaps/._Russian_Blue_178.png
# annotations/trimaps/Russian_Blue_178.png
# annotations/trimaps/._Russian_Blue_179.png
# annotations/trimaps/Russian_Blue_179.png
# annotations/trimaps/._Russian_Blue_18.png
# annotations/trimaps/Russian_Blue_18.png
# annotations/trimaps/._Russian_Blue_180.png
# annotations/trimaps/Russian_Blue_180.png
# annotations/trimaps/._Russian_Blue_181.png
# annotations/trimaps/Russian_Blue_181.png
# annotations/trimaps/._Russian_Blue_182.png
# annotations/trimaps/Russian_Blue_182.png
# annotations/trimaps/._Russian_Blue_183.png
# annotations/trimaps/Russian_Blue_183.png
# annotations/trimaps/._Russian_Blue_184.png
# annotations/trimaps/Russian_Blue_184.png
# annotations/trimaps/._Russian_Blue_185.png
# annotations/trimaps/Russian_Blue_185.png
# annotations/trimaps/._Russian_Blue_186.png
# annotations/trimaps/Russian_Blue_186.png
# annotations/trimaps/._Russian_Blue_187.png
# annotations/trimaps/Russian_Blue_187.png
# annotations/trimaps/._Russian_Blue_188.png
# annotations/trimaps/Russian_Blue_188.png
# annotations/trimaps/._Russian_Blue_19.png
# annotations/trimaps/Russian_Blue_19.png
# annotations/trimaps/._Russian_Blue_191.png
# annotations/trimaps/Russian_Blue_191.png
# annotations/trimaps/._Russian_Blue_192.png
# annotations/trimaps/Russian_Blue_192.png
# annotations/trimaps/._Russian_Blue_193.png
# annotations/trimaps/Russian_Blue_193.png
# annotations/trimaps/._Russian_Blue_194.png
# annotations/trimaps/Russian_Blue_194.png
# annotations/trimaps/._Russian_Blue_195.png
# annotations/trimaps/Russian_Blue_195.png
# annotations/trimaps/._Russian_Blue_196.png
# annotations/trimaps/Russian_Blue_196.png
# annotations/trimaps/._Russian_Blue_197.png
# annotations/trimaps/Russian_Blue_197.png
# annotations/trimaps/._Russian_Blue_198.png
# annotations/trimaps/Russian_Blue_198.png
# annotations/trimaps/._Russian_Blue_199.png
# annotations/trimaps/Russian_Blue_199.png
# annotations/trimaps/._Russian_Blue_20.png
# annotations/trimaps/Russian_Blue_20.png
# annotations/trimaps/._Russian_Blue_200.png
# annotations/trimaps/Russian_Blue_200.png
# annotations/trimaps/._Russian_Blue_201.png
# annotations/trimaps/Russian_Blue_201.png
# annotations/trimaps/._Russian_Blue_202.png
# annotations/trimaps/Russian_Blue_202.png
# annotations/trimaps/._Russian_Blue_203.png
# annotations/trimaps/Russian_Blue_203.png
# annotations/trimaps/._Russian_Blue_204.png
# annotations/trimaps/Russian_Blue_204.png
# annotations/trimaps/._Russian_Blue_205.png
# annotations/trimaps/Russian_Blue_205.png
# annotations/trimaps/._Russian_Blue_206.png
# annotations/trimaps/Russian_Blue_206.png
# annotations/trimaps/._Russian_Blue_207.png
# annotations/trimaps/Russian_Blue_207.png
# annotations/trimaps/._Russian_Blue_208.png
# annotations/trimaps/Russian_Blue_208.png
# annotations/trimaps/._Russian_Blue_209.png
# annotations/trimaps/Russian_Blue_209.png
# annotations/trimaps/._Russian_Blue_21.png
# annotations/trimaps/Russian_Blue_21.png
# annotations/trimaps/._Russian_Blue_211.png
# annotations/trimaps/Russian_Blue_211.png
# annotations/trimaps/._Russian_Blue_212.png
# annotations/trimaps/Russian_Blue_212.png
# annotations/trimaps/._Russian_Blue_215.png
# annotations/trimaps/Russian_Blue_215.png
# annotations/trimaps/._Russian_Blue_216.png
# annotations/trimaps/Russian_Blue_216.png
# annotations/trimaps/._Russian_Blue_220.png
# annotations/trimaps/Russian_Blue_220.png
# annotations/trimaps/._Russian_Blue_221.png
# annotations/trimaps/Russian_Blue_221.png
# annotations/trimaps/._Russian_Blue_222.png
# annotations/trimaps/Russian_Blue_222.png
# annotations/trimaps/._Russian_Blue_226.png
# annotations/trimaps/Russian_Blue_226.png
# annotations/trimaps/._Russian_Blue_228.png
# annotations/trimaps/Russian_Blue_228.png
# annotations/trimaps/._Russian_Blue_232.png
# annotations/trimaps/Russian_Blue_232.png
# annotations/trimaps/._Russian_Blue_236.png
# annotations/trimaps/Russian_Blue_236.png
# annotations/trimaps/._Russian_Blue_237.png
# annotations/trimaps/Russian_Blue_237.png
# annotations/trimaps/._Russian_Blue_239.png
# annotations/trimaps/Russian_Blue_239.png
# annotations/trimaps/._Russian_Blue_24.png
# annotations/trimaps/Russian_Blue_24.png
# annotations/trimaps/._Russian_Blue_240.png
# annotations/trimaps/Russian_Blue_240.png
# annotations/trimaps/._Russian_Blue_242.png
# annotations/trimaps/Russian_Blue_242.png
# annotations/trimaps/._Russian_Blue_244.png
# annotations/trimaps/Russian_Blue_244.png
# annotations/trimaps/._Russian_Blue_253.png
# annotations/trimaps/Russian_Blue_253.png
# annotations/trimaps/._Russian_Blue_258.png
# annotations/trimaps/Russian_Blue_258.png
# annotations/trimaps/._Russian_Blue_262.png
# annotations/trimaps/Russian_Blue_262.png
# annotations/trimaps/._Russian_Blue_263.png
# annotations/trimaps/Russian_Blue_263.png
# annotations/trimaps/._Russian_Blue_264.png
# annotations/trimaps/Russian_Blue_264.png
# annotations/trimaps/._Russian_Blue_27.png
# annotations/trimaps/Russian_Blue_27.png
# annotations/trimaps/._Russian_Blue_28.png
# annotations/trimaps/Russian_Blue_28.png
# annotations/trimaps/._Russian_Blue_29.png
# annotations/trimaps/Russian_Blue_29.png
# annotations/trimaps/._Russian_Blue_30.png
# annotations/trimaps/Russian_Blue_30.png
# annotations/trimaps/._Russian_Blue_31.png
# annotations/trimaps/Russian_Blue_31.png
# annotations/trimaps/._Russian_Blue_32.png
# annotations/trimaps/Russian_Blue_32.png
# annotations/trimaps/._Russian_Blue_33.png
# annotations/trimaps/Russian_Blue_33.png
# ...
# annotations/trimaps/yorkshire_terrier_86.png
# annotations/trimaps/._yorkshire_terrier_87.png
# annotations/trimaps/yorkshire_terrier_87.png
# annotations/trimaps/._yorkshire_terrier_88.png
# annotations/trimaps/yorkshire_terrier_88.png
# annotations/trimaps/._yorkshire_terrier_89.png
# annotations/trimaps/yorkshire_terrier_89.png
# annotations/trimaps/._yorkshire_terrier_9.png
# annotations/trimaps/yorkshire_terrier_9.png
# annotations/trimaps/._yorkshire_terrier_90.png
# annotations/trimaps/yorkshire_terrier_90.png
# annotations/trimaps/._yorkshire_terrier_91.png
# annotations/trimaps/yorkshire_terrier_91.png
# annotations/trimaps/._yorkshire_terrier_92.png
# annotations/trimaps/yorkshire_terrier_92.png
# annotations/trimaps/._yorkshire_terrier_93.png
# annotations/trimaps/yorkshire_terrier_93.png
# annotations/trimaps/._yorkshire_terrier_94.png
# annotations/trimaps/yorkshire_terrier_94.png
# annotations/trimaps/._yorkshire_terrier_95.png
# annotations/trimaps/yorkshire_terrier_95.png
# annotations/trimaps/._yorkshire_terrier_96.png
# annotations/trimaps/yorkshire_terrier_96.png
# annotations/trimaps/._yorkshire_terrier_97.png
# annotations/trimaps/yorkshire_terrier_97.png
# annotations/trimaps/._yorkshire_terrier_98.png
# annotations/trimaps/yorkshire_terrier_98.png
# annotations/trimaps/._yorkshire_terrier_99.png
# annotations/trimaps/yorkshire_terrier_99.png

# %% [markdown]
# ### 이미지 디렉토리와 annotation 파일 살펴 보기

# %%
# !ls -lia ./data/images/Abyss*.jpg
# Out:
# 3055750 -rwxr-xr-x 1 1001 1001 126923 Jun 18  2012 ./data/images/Abyssinian_100.jpg
# 3058295 -rwxr-xr-x 1 1001 1001  49023 Jun 18  2012 ./data/images/Abyssinian_101.jpg
# 3059371 -rwxr-xr-x 1 1001 1001 165505 Jun 18  2012 ./data/images/Abyssinian_102.jpg
# 3060143 -rwxr-xr-x 1 1001 1001 132937 Jun 18  2012 ./data/images/Abyssinian_103.jpg
# 3060293 -rwxr-xr-x 1 1001 1001  34907 Jun 18  2012 ./data/images/Abyssinian_104.jpg
# 3058674 -rwxr-xr-x 1 1001 1001 141823 Jun 18  2012 ./data/images/Abyssinian_105.jpg
# 3054831 -rwxr-xr-x 1 1001 1001 197092 Jun 18  2012 ./data/images/Abyssinian_106.jpg
# 3060184 -rwxr-xr-x 1 1001 1001 150955 Jun 18  2012 ./data/images/Abyssinian_107.jpg
# 3057125 -rwxr-xr-x 1 1001 1001 120641 Jun 18  2012 ./data/images/Abyssinian_108.jpg
# 3058663 -rwxr-xr-x 1 1001 1001  13601 Jun 18  2012 ./data/images/Abyssinian_109.jpg
# 3054291 -rwxr-xr-x 1 1001 1001  96294 Jun 18  2012 ./data/images/Abyssinian_10.jpg
# 3057078 -rwxr-xr-x 1 1001 1001  27734 Jun 18  2012 ./data/images/Abyssinian_110.jpg
# 3054766 -rwxr-xr-x 1 1001 1001 132097 Jun 18  2012 ./data/images/Abyssinian_111.jpg
# 3056780 -rwxr-xr-x 1 1001 1001 144288 Jun 18  2012 ./data/images/Abyssinian_112.jpg
# 3057556 -rwxr-xr-x 1 1001 1001 157030 Jun 18  2012 ./data/images/Abyssinian_81.jpg
# 3054338 -rwxr-xr-x 1 1001 1001  19529 Jun 18  2012 ./data/images/Abyssinian_82.jpg
# 3057441 -rwxr-xr-x 1 1001 1001  93889 Jun 18  2012 ./data/images/Abyssinian_83.jpg
# 3060246 -rwxr-xr-x 1 1001 1001  28989 Jun 18  2012 ./data/images/Abyssinian_84.jpg
# 3054221 -rwxr-xr-x 1 1001 1001 135621 Jun 18  2012 ./data/images/Abyssinian_85.jpg
# 3054378 -rwxr-xr-x 1 1001 1001  91601 Jun 18  2012 ./data/images/Abyssinian_86.jpg
# 3056711 -rwxr-xr-x 1 1001 1001  32264 Jun 18  2012 ./data/images/Abyssinian_87.jpg
# 3056217 -rwxr-xr-x 1 1001 1001 188320 Jun 18  2012 ./data/images/Abyssinian_88.jpg
# 3059605 -rwxr-xr-x 1 1001 1001 197461 Jun 18  2012 ./data/images/Abyssinian_89.jpg
# 3057149 -rwxr-xr-x 1 1001 1001  60253 Jun 18  2012 ./data/images/Abyssinian_8.jpg
# 3058677 -rwxr-xr-x 1 1001 1001 162676 Jun 18  2012 ./data/images/Abyssinian_90.jpg
# 3058263 -rwxr-xr-x 1 1001 1001  11907 Jun 18  2012 ./data/images/Abyssinian_91.jpg
# 3058877 -rwxr-xr-x 1 1001 1001 187682 Jun 18  2012 ./data/images/Abyssinian_92.jpg
# 3058092 -rwxr-xr-x 1 1001 1001 178036 Jun 18  2012 ./data/images/Abyssinian_93.jpg
# 3056951 -rwxr-xr-x 1 1001 1001  96141 Jun 18  2012 ./data/images/Abyssinian_94.jpg
# 3060440 -rwxr-xr-x 1 1001 1001 121257 Jun 18  2012 ./data/images/Abyssinian_95.jpg
# 3056079 -rwxr-xr-x 1 1001 1001 124408 Jun 18  2012 ./data/images/Abyssinian_96.jpg
# 3055626 -rwxr-xr-x 1 1001 1001 141857 Jun 18  2012 ./data/images/Abyssinian_97.jpg
# 3059960 -rwxr-xr-x 1 1001 1001 130825 Jun 18  2012 ./data/images/Abyssinian_98.jpg
# 3055431 -rwxr-xr-x 1 1001 1001 156022 Jun 18  2012 ./data/images/Abyssinian_99.jpg
# 3054639 -rwxr-xr-x 1 1001 1001  21004 Jun 18  2012 ./data/images/Abyssinian_9.jpg

# %%
# !ls -lia ./data/images

# %%
# !cat ./data/annotations/xmls/Abyssinian_1.xml
# Out:
# <annotation><folder>OXIIIT</folder><filename>Abyssinian_1.jpg</filename><source><database>OXFORD-IIIT Pet Dataset</database><annotation>OXIIIT</annotation>flickr</source><size><width>600</width><height>400</height><depth>3</depth></size><segmented>0</segmented><object><name>cat</name><pose>Frontal</pose><truncated>0</truncated><occluded>0</occluded><bndbox><xmin>333</xmin><ymin>72</ymin><xmax>425</xmax><ymax>158</ymax></bndbox><difficult>0</difficult></object></annotation>

# %%
import glob
import xml.etree.ElementTree as ET

# annotation xml 파일 파싱해서 bbox정보 추출
def get_bboxes_from_xml_test(xml_file):
  tree = ET.parse(xml_file)
  root = tree.getroot()
  bbox_names = []
  bboxes = []
  # 파일내에 있는 모든 object Element를 찾음.
  for obj in root.findall('object'):

    bbox_name = obj.find('name').text
    xmlbox = obj.find('bndbox')
    x1 = int(xmlbox.find('xmin').text)
    y1 = int(xmlbox.find('ymin').text)
    x2 = int(xmlbox.find('xmax').text)
    y2 = int(xmlbox.find('ymax').text)

    bbox_names.append(bbox_name)
    bboxes.append([x1, y1, x2, y2])

  return bbox_names, bboxes

get_bboxes_from_xml_test('./data/annotations/xmls/Abyssinian_1.xml')
# Out:
# (['cat'], [[333, 72, 425, 158]])

# %%
# !ls -lia ./data/annotations/xmls/Abys*.xml

# %% [markdown]
# ### train, val image/annotation 메타 파일 보기
# * train과 valid 데이터로 나뉠 image와 annotation의 파일명을 가지는 메타 파일
# * train과 valid용 meta 파일을 별도로 만듬.

# %%
# !cd ./data/annotations; cat trainval.txt

# %%
import pandas as pd

pet_df = pd.read_csv('./data/annotations/trainval.txt', sep=' ', header=None, names=['img_name', 'class_id', 'etc1', 'etc2'])
pet_df.head()
# Out:
#          img_name  class_id  etc1  etc2
# 0  Abyssinian_100         1     1     1
# 1  Abyssinian_101         1     1     1
# 2  Abyssinian_102         1     1     1
# 3  Abyssinian_103         1     1     1
# 4  Abyssinian_104         1     1     1

# %%
pet_df['class_id'].value_counts()
# Out:
# 1     100
# 28    100
# 21    100
# 22    100
# 24    100
# 25    100
# 26    100
# 27    100
# 29    100
# 2     100
# 30    100
# 31    100
# 32    100
# 34    100
# 35    100
# 36    100
# 20    100
# 19    100
# 18    100
# 17    100
# 3     100
# 4     100
# 5     100
# 6     100
# 7     100
# 9     100
# 10    100
# 11    100
# 14    100
# 15    100
# 16    100
# 37    100
# 33     99
# 8      96
# 13     96
# 23     96
# 12     93
# Name: class_id, dtype: int64

# %%
pet_df['class_name'] = pet_df['img_name'].apply(lambda x:x[:x.rfind('_')])
pet_df.head()
# Out:
#          img_name  class_id  etc1  etc2  class_name
# 0  Abyssinian_100         1     1     1  Abyssinian
# 1  Abyssinian_101         1     1     1  Abyssinian
# 2  Abyssinian_102         1     1     1  Abyssinian
# 3  Abyssinian_103         1     1     1  Abyssinian
# 4  Abyssinian_104         1     1     1  Abyssinian

# %%
from sklearn.model_selection import train_test_split

train_df, val_df = train_test_split(pet_df, test_size=0.1, stratify=pet_df['class_id'], random_state=2021)

# %%
print(train_df['class_id'].value_counts(), val_df['class_id'].value_counts())
# Out:
# 11    90
# 19    90
# 2     90
# 27    90
# 6     90
# 31    90
# 16    90
# 26    90
# 22    90
# 36    90
# 28    90
# 5     90
# 35    90
# 9     90
# 32    90
# 37    90
# 1     90
# 14    90
# 34    90
# 7     90
# 20    90
# 29    90
# 21    90
# 4     90
# 25    90
# 10    90
# 3     90
# 15    90
# 17    90
# 30    90
# 24    90
# 18    90
# 33    89
# 23    87
# 8     86
# 13    86
# 12    84
# Name: class_id, dtype: int64 19    10
# 29    10
# 4     10
# 11    10
# 13    10
# 37    10
# 27    10
# 22    10
# 14    10
# 8     10
# 16    10
# 35    10
# 2     10
# 31    10
# 33    10
# 30    10
# 18    10
# 24    10
# 3     10
# 17    10
# 28    10
# 25    10
# 9     10
# 32    10
# 21    10
# 26    10
# 36    10
# 10    10
# 20    10
# 1     10
# 34    10
# 7     10
# 5     10
# 15    10
# 6     10
# 23     9
# 12     9
# Name: class_id, dtype: int64

# %%
train_df = train_df.sort_values(by='img_name')
val_df = val_df.sort_values(by='img_name')

# %%
# ann_file로 주어지는 메타파일은 가급적이면 소스데이터의 가장 상단 디렉토리에 저장하는 것이 바람직.
train_df['img_name'].to_csv('./data/train.txt', sep=' ', header=False, index=False)
val_df['img_name'].to_csv('./data/val.txt', sep=' ', header=False, index=False)

# %%
train_df.head()
# Out:
#             img_name  class_id  etc1  etc2  class_name
# 1895    Abyssinian_1         1     1     1  Abyssinian
# 10     Abyssinian_10         1     1     1  Abyssinian
# 1     Abyssinian_101         1     1     1  Abyssinian
# 2     Abyssinian_102         1     1     1  Abyssinian
# 3     Abyssinian_103         1     1     1  Abyssinian

# %%
pet_classes_list = pet_df['class_name'].unique().tolist()
print(pet_classes_list)
# Out:
# ['Abyssinian', 'american_bulldog', 'american_pit_bull_terrier', 'basset_hound', 'beagle', 'Bengal', 'Birman', 'Bombay', 'boxer', 'British_Shorthair', 'chihuahua', 'Egyptian_Mau', 'english_cocker_spaniel', 'english_setter', 'german_shorthaired', 'great_pyrenees', 'havanese', 'japanese_chin', 'keeshond', 'leonberger', 'Maine_Coon', 'miniature_pinscher', 'newfoundland', 'Persian', 'pomeranian', 'pug', 'Ragdoll', 'Russian_Blue', 'saint_bernard', 'samoyed', 'scottish_terrier', 'shiba_inu', 'Siamese', 'Sphynx', 'staffordshire_bull_terrier', 'wheaten_terrier', 'yorkshire_terrier']

# %%
# !echo 'train list #####'; cat ./data/train.txt
# Out:
# train list #####
# Abyssinian_1
# Abyssinian_10
# Abyssinian_101
# Abyssinian_102
# Abyssinian_103
# Abyssinian_104
# Abyssinian_105
# Abyssinian_106
# Abyssinian_107
# Abyssinian_108
# Abyssinian_109
# Abyssinian_110
# Abyssinian_111
# Abyssinian_112
# Abyssinian_113
# Abyssinian_114
# Abyssinian_115
# Abyssinian_116
# Abyssinian_117
# Abyssinian_118
# Abyssinian_119
# Abyssinian_12
# Abyssinian_120
# Abyssinian_121
# Abyssinian_123
# Abyssinian_124
# Abyssinian_125
# Abyssinian_126
# Abyssinian_128
# Abyssinian_129
# Abyssinian_13
# Abyssinian_130
# Abyssinian_131
# Abyssinian_132
# Abyssinian_133
# Abyssinian_134
# Abyssinian_135
# Abyssinian_136
# Abyssinian_137
# Abyssinian_138
# Abyssinian_139
# Abyssinian_14
# Abyssinian_141
# Abyssinian_142
# Abyssinian_143
# Abyssinian_144
# Abyssinian_145
# Abyssinian_146
# Abyssinian_148
# Abyssinian_149
# Abyssinian_15
# Abyssinian_150
# Abyssinian_151
# Abyssinian_152
# Abyssinian_154
# Abyssinian_155
# Abyssinian_156
# Abyssinian_157
# Abyssinian_159
# Abyssinian_16
# Abyssinian_160
# Abyssinian_161
# Abyssinian_164
# american_pit_bull_terrier_134
# american_pit_bull_terrier_135
# american_pit_bull_terrier_136
# american_pit_bull_terrier_137
# american_pit_bull_terrier_138
# american_pit_bull_terrier_139
# american_pit_bull_terrier_14
# american_pit_bull_terrier_140
# american_pit_bull_terrier_141
# american_pit_bull_terrier_142
# american_pit_bull_terrier_143
# american_pit_bull_terrier_144
# american_pit_bull_terrier_145
# american_pit_bull_terrier_146
# american_pit_bull_terrier_147
# american_pit_bull_terrier_148
# american_pit_bull_terrier_149
# american_pit_bull_terrier_15
# american_pit_bull_terrier_150
# american_pit_bull_terrier_151
# american_pit_bull_terrier_152
# american_pit_bull_terrier_153
# american_pit_bull_terrier_154
# american_pit_bull_terrier_155
# american_pit_bull_terrier_158
# american_pit_bull_terrier_159
# american_pit_bull_terrier_16
# american_pit_bull_terrier_160
# american_pit_bull_terrier_161
# american_pit_bull_terrier_162
# american_pit_bull_terrier_163
# american_pit_bull_terrier_164
# american_pit_bull_terrier_165
# american_pit_bull_terrier_166
# american_pit_bull_terrier_167
# american_pit_bull_terrier_168
# american_pit_bull_terrier_17
# american_pit_bull_terrier_170
# american_pit_bull_terrier_171
# american_pit_bull_terrier_172
# american_pit_bull_terrier_173
# american_pit_bull_terrier_174
# american_pit_bull_terrier_175
# american_pit_bull_terrier_176
# american_pit_bull_terrier_177
# american_pit_bull_terrier_178
# american_pit_bull_terrier_179
# american_pit_bull_terrier_18
# american_pit_bull_terrier_180
# american_pit_bull_terrier_181
# american_pit_bull_terrier_182
# american_pit_bull_terrier_183
# american_pit_bull_terrier_184
# american_pit_bull_terrier_185
# american_pit_bull_terrier_186
# american_pit_bull_terrier_187
# american_pit_bull_terrier_188
# american_pit_bull_terrier_189
# basset_hound_10
# basset_hound_100
# basset_hound_101
# basset_hound_102
# basset_hound_103
# basset_hound_104
# basset_hound_105
# basset_hound_106
# basset_hound_107
# basset_hound_109
# basset_hound_11
# basset_hound_110
# basset_hound_111
# basset_hound_112
# basset_hound_113
# basset_hound_114
# basset_hound_115
# basset_hound_116
# basset_hound_117
# basset_hound_119
# basset_hound_12
# basset_hound_120
# basset_hound_122
# basset_hound_123
# basset_hound_124
# basset_hound_125
# basset_hound_126
# basset_hound_127
# basset_hound_129
# basset_hound_13
# basset_hound_130
# basset_hound_131
# basset_hound_132
# basset_hound_133
# basset_hound_134
# basset_hound_135
# basset_hound_136
# basset_hound_137
# basset_hound_138
# basset_hound_139
# basset_hound_140
# basset_hound_141
# basset_hound_142
# basset_hound_143
# basset_hound_144
# basset_hound_145
# basset_hound_146
# basset_hound_148
# basset_hound_149
# basset_hound_15
# basset_hound_150
# basset_hound_151
# basset_hound_152
# basset_hound_153
# basset_hound_154
# basset_hound_155
# basset_hound_156
# basset_hound_157
# basset_hound_158
# basset_hound_159
# basset_hound_16
# basset_hound_160
# basset_hound_161
# basset_hound_162
# basset_hound_163
# basset_hound_164
# basset_hound_165
# basset_hound_166
# basset_hound_167
# basset_hound_168
# basset_hound_169
# basset_hound_17
# basset_hound_170
# basset_hound_171
# basset_hound_172
# basset_hound_173
# * CLASSES 는 pet_df의 'class_name' 컬럼에 unique 데이터로 지정. class id는 tuple(list)형의 CLASSES의 index값에 따라 설정.
# * ann_file로 입력되는 메타 파일을 읽어서 개별 image정보와 ann 정보를 dict로 생성하여 data_infos list에 입력
# * 개별 XML 읽어서 ann 정보를 만드는 것은 get_bboxes_from_xml() 함수 이용.
# * 디버깅용으로 CustomDataset을 만들어서 미리 테스트 하는 방법도 고려.
#
# ![mmdetection_anno.png](data:image/png;base64,...)

# %%
import xml.etree.ElementTree as ET

# 1개의 annotation 파일에서 bbox 정보 추출. 여러개의 object가 있을 경우 이들 object의 name과 bbox 좌표들을 list로 반환.
def get_bboxes_from_xml(anno_dir, xml_file):
  anno_xml_file = osp.join(anno_dir, xml_file)
  tree = ET.parse(anno_xml_file)
  root = tree.getroot()
  bbox_names = []
  bboxes = []

  # 파일내에 있는 모든 object Element를 찾음.
  for obj in root.findall('object'):
    #obj.find('name').text는 cat 이나 dog을 반환
    #bbox_name = obj.find('name').text
    # object의 클래스명은 파일명에서 추출.
    bbox_name = xml_file[:xml_file.rfind('_')]

    xmlbox = obj.find('bndbox')
    x1 = int(xmlbox.find('xmin').text)
    y1 = int(xmlbox.find('ymin').text)
    x2 = int(xmlbox.find('xmax').text)
    y2 = int(xmlbox.find('ymax').text)

    bboxes.append([x1, y1, x2, y2])
    bbox_names.append(bbox_name)

  return bbox_names, bboxes

# %%
import copy
import os.path as osp

import mmcv
import numpy as np
import cv2

from mmdet.datasets.builder import DATASETS
from mmdet.datasets.custom import CustomDataset

import xml.etree.ElementTree as ET

PET_CLASSES = pet_df['class_name'].unique().tolist()

@DATASETS.register_module(force=True)
class PetDataset(CustomDataset):
  CLASSES = PET_CLASSES

  # annotation에 대한 모든 파일명을 가지고 있는 텍스트 파일을 __init__(self, ann_file)로 입력 받고,
  # 이 self.ann_file이 load_annotations()의 인자로 입력
  def load_annotations(self, ann_file):
    cat2label = {k:i for i, k in enumerate(self.CLASSES)}
    image_list = mmcv.list_from_file(self.ann_file)
    # 포맷 중립 데이터를 담을 list 객체
    data_infos = []

    for image_id in image_list:
      # self.img_prefix는 images 가 입력될 것임.
      filename = '{0:}/{1:}.jpg'.format(self.img_prefix, image_id)
      # 원본 이미지의 너비, 높이를 image를 직접 로드하여 구함.
      image = cv2.imread(filename)
      height, width = image.shape[:2]
      # 개별 image의 annotation 정보 저장용 Dict 생성. key값 filename에는 image의 파일명만 들어감(디렉토리는 제외)
      # 영상에는 data_info = {'filename': filename 으로 되어 있으나 filename은 image 파일명만 들어가는게 맞음.
      data_info = {'filename': str(image_id) + '.jpg',
                  'width': width, 'height': height}
      # 개별 annotation XML 파일이 있는 서브 디렉토리의 prefix 변환.
      label_prefix = self.img_prefix.replace('images', 'annotations')

      # 개별 annotation XML 파일을 1개 line 씩 읽어서 list 로드. annotation XML파일이 xmls 밑에 있음에 유의
      anno_xml_file = osp.join(label_prefix, 'xmls/'+str(image_id)+'.xml')
      # 메타 파일에는 이름이 있으나 실제로는 존재하지 않는 XML이 있으므로 이는 제외.
      if not osp.exists(anno_xml_file):
          continue

      # get_bboxes_from_xml() 를 이용하여 개별 XML 파일에 있는 이미지의 모든 bbox 정보를 list 객체로 생성.
      anno_dir = osp.join(label_prefix, 'xmls')
      bbox_names, bboxes = get_bboxes_from_xml(anno_dir, str(image_id)+'.xml')
      #print('#########:', bbox_names)

      gt_bboxes = []
      gt_labels = []
      gt_bboxes_ignore = []
      gt_labels_ignore = []

      # bbox별 Object들의 class name을 class id로 매핑. class id는 tuple(list)형의 CLASSES의 index값에 따라 설정
      for bbox_name, bbox in zip(bbox_names, bboxes):
        # 만약 bbox_name이 클래스명에 해당 되면, gt_bboxes와 gt_labels에 추가, 그렇지 않으면 gt_bboxes_ignore, gt_labels_ignore에 추가
        # bbox_name이 CLASSES중에 반드시 하나 있어야 함. 안 그러면 FILTERING 되므로 주의 할것.
        if bbox_name in cat2label:
            gt_bboxes.append(bbox)
            # gt_labels에는 class id를 입력
            gt_labels.append(cat2label[bbox_name])
        else:
            gt_bboxes_ignore.append(bbox)
            gt_labels_ignore.append(-1)

      # 개별 image별 annotation 정보를 가지는 Dict 생성. 해당 Dict의 value값을 np.array형태로 bbox의 좌표와 label값으로 생성.
      data_anno = {
        'bboxes': np.array(gt_bboxes, dtype=np.float32).reshape(-1, 4),
        'labels': np.array(gt_labels, dtype=np.long),
        'bboxes_ignore': np.array(gt_bboxes_ignore, dtype=np.float32).reshape(-1, 4),
        'labels_ignore': np.array(gt_labels_ignore, dtype=np.long)
      }

      # image에 대한 메타 정보를 가지는 data_info Dict에 'ann' key값으로 data_anno를 value로 저장.
      data_info.update(ann=data_anno)
      # 전체 annotation 파일들에 대한 정보를 가지는 data_infos에 data_info Dict를 추가
      data_infos.append(data_info)
      #print(data_info)

    return data_infos

# %%
mmcv.list_from_file('/content/data/train.txt')

# %%
''' 디버깅 용도로 CustomDataset을 흉내낸 클래스를 생성하여 다양한 테스트를 수행 가능 '''

import os.path as osp

PET_CLASSES = pet_df['class_name'].unique().tolist()

# 디버깅 용도로 CustomDataset을 흉내낸 클래스 생성.
class PetDataset_imsi():
  CLASSES = PET_CLASSES

  # 생성자 함수 생성.
  def __init__(self, data_root, ann_file, img_prefix):
      self.data_root = data_root
      self.ann_file = osp.join(data_root, ann_file)
      self.img_prefix = osp.join(data_root, img_prefix)

      self.data_infos = self.load_annotations(self.ann_file)

  # annotation에 대한 모든 파일명을 가지고 있는 텍스트 파일을 __init__(self, ann_file)로 입력 받고,
  # 이 self.ann_file이 load_annotations()의 인자로 입력
  def load_annotations(self, ann_file):
    cat2label = {k:i for i, k in enumerate(self.CLASSES)}
    image_list = mmcv.list_from_file(self.ann_file)
    # 포맷 중립 데이터를 담을 list 객체
    data_infos = []

    for image_id in image_list:
      # self.img_prefix는 images 가 입력될 것임.
      filename = '{0:}/{1:}.jpg'.format(self.img_prefix, image_id)
      # 원본 이미지의 너비, 높이를 image를 직접 로드하여 구함.
      image = cv2.imread(filename)
      height, width = image.shape[:2]
      # 개별 image의 annotation 정보 저장용 Dict 생성. key값 filename에는 image의 파일명만 들어감(디렉토리는 제외)
      # 영상에는 data_info = {'filename': filename 으로 되어 있으나 filename은 image 파일명만 들어가는게 맞음.
      data_info = {'filename': str(image_id) + '.jpg',
                  'width': width, 'height': height}
      # 개별 annotation XML 파일이 있는 서브 디렉토리의 prefix 변환.
      label_prefix = self.img_prefix.replace('images', 'annotations')

      # 개별 annotation XML 파일을 1개 line 씩 읽어서 list 로드. annotation XML파일이 xmls 밑에 있음에 유의
      anno_xml_file = osp.join(label_prefix, 'xmls/'+str(image_id)+'.xml')
      # 메타 파일에는 이름이 있으나 실제로는 존재하지 않는 XML이 있으므로 이는 제외.
      if not osp.exists(anno_xml_file):
          continue

      # get_bboxes_from_xml() 를 이용하여 개별 XML 파일에 있는 이미지의 모든 bbox 정보를 list 객체로 생성.
      anno_dir = osp.join(label_prefix, 'xmls')
      bbox_names, bboxes = get_bboxes_from_xml(anno_dir, str(image_id)+'.xml')
      #print('#########:', bbox_names)

      gt_bboxes = []
      gt_labels = []
      gt_bboxes_ignore = []
      gt_labels_ignore = []

      # bbox별 Object들의 class name을 class id로 매핑. class id는 tuple(list)형의 CLASSES의 index값에 따라 설정
      for bbox_name, bbox in zip(bbox_names, bboxes):
        # 만약 bbox_name이 클래스명에 해당 되면, gt_bboxes와 gt_labels에 추가, 그렇지 않으면 gt_bboxes_ignore, gt_labels_ignore에 추가
        # bbox_name이 CLASSES중에 반드시 하나 있어야 함. 안 그러면 FILTERING 되므로 주의 할것.
        if bbox_name in cat2label:
            gt_bboxes.append(bbox)
            # gt_labels에는 class id를 입력
            gt_labels.append(cat2label[bbox_name])
        else:
            gt_bboxes_ignore.append(bbox)
            gt_labels_ignore.append(-1)

      # 개별 image별 annotation 정보를 가지는 Dict 생성. 해당 Dict의 value값을 np.array형태로 bbox의 좌표와 label값으로 생성.
      data_anno = {
        'bboxes': np.array(gt_bboxes, dtype=np.float32).reshape(-1, 4),
        'labels': np.array(gt_labels, dtype=np.long),
        'bboxes_ignore': np.array(gt_bboxes_ignore, dtype=np.float32).reshape(-1, 4),
        'labels_ignore': np.array(gt_labels_ignore, dtype=np.long)
      }

      # image에 대한 메타 정보를 가지는 data_info Dict에 'ann' key값으로 data_anno를 value로 저장.
      data_info.update(ann=data_anno)
      # 전체 annotation 파일들에 대한 정보를 가지는 data_infos에 data_info Dict를 추가
      data_infos.append(data_info)
      #print(data_info)

    return data_infos

# %%
# 디버깅 용도로 생성한 클래스를 생성하고 data_infos를 10개만 추출하여 생성된 데이터 확인.
train_ds = PetDataset_imsi(data_root='/content/data', ann_file='train.txt', img_prefix='images')
print(train_ds.data_infos[:10])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:71: DeprecationWarning: `np.long` is a deprecated alias for `np.compat.long`. To silence this warning, use `np.compat.long` by itself. In the likely event your code does not need to work on Python 2 you can use the builtin `int` for which `np.compat.long` is itself an alias. Doing this will not modify any behaviour and is safe. When replacing `np.long`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: DeprecationWarning: `np.long` is a deprecated alias for `np.compat.long`. To silence this warning, use `np.compat.long` by itself. In the likely event your code does not need to work on Python 2 you can use the builtin `int` for which `np.compat.long` is itself an alias. Doing this will not modify any behaviour and is safe. When replacing `np.long`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# [{'filename': 'Abyssinian_1.jpg', 'width': 600, 'height': 400, 'ann': {'bboxes': array([[333.,  72., 425., 158.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}, {'filename': 'Abyssinian_10.jpg', 'width': 375, 'height': 500, 'ann': {'bboxes': array([[ 72., 105., 288., 291.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}, {'filename': 'Abyssinian_101.jpg', 'width': 450, 'height': 313, 'ann': {'bboxes': array([[ 54.,  36., 319., 235.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}, {'filename': 'Abyssinian_102.jpg', 'width': 500, 'height': 465, 'ann': {'bboxes': array([[ 23.,  27., 325., 320.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}, {'filename': 'Abyssinian_103.jpg', 'width': 500, 'height': 351, 'ann': {'bboxes': array([[241.,  68., 362., 196.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}, {'filename': 'Abyssinian_105.jpg', 'width': 500, 'height': 375, 'ann': {'bboxes': array([[237., 101., 373., 227.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}, {'filename': 'Abyssinian_106.jpg', 'width': 1536, 'height': 1024, 'ann': {'bboxes': array([[ 861.,  156., 1302.,  563.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}, {'filename': 'Abyssinian_107.jpg', 'width': 500, 'height': 448, 'ann': {'bboxes': array([[ 94.,  76., 275., 271.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}, {'filename': 'Abyssinian_108.jpg', 'width': 500, 'height': 404, 'ann': {'bboxes': array([[ 50.,  14., 336., 304.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}, {'filename': 'Abyssinian_109.jpg', 'width': 282, 'height': 450, 'ann': {'bboxes': array([[ 81.,   7., 246., 146.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}]

# %%
print(train_ds.data_infos[:10])
# Out:
# [{'filename': 'Abyssinian_1.jpg', 'width': 600, 'height': 400, 'ann': {'bboxes': array([[333.,  72., 425., 158.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}, {'filename': 'Abyssinian_10.jpg', 'width': 375, 'height': 500, 'ann': {'bboxes': array([[ 72., 105., 288., 291.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}, {'filename': 'Abyssinian_101.jpg', 'width': 450, 'height': 313, 'ann': {'bboxes': array([[ 54.,  36., 319., 235.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}, {'filename': 'Abyssinian_102.jpg', 'width': 500, 'height': 465, 'ann': {'bboxes': array([[ 23.,  27., 325., 320.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}, {'filename': 'Abyssinian_103.jpg', 'width': 500, 'height': 351, 'ann': {'bboxes': array([[241.,  68., 362., 196.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}, {'filename': 'Abyssinian_105.jpg', 'width': 500, 'height': 375, 'ann': {'bboxes': array([[237., 101., 373., 227.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}, {'filename': 'Abyssinian_106.jpg', 'width': 1536, 'height': 1024, 'ann': {'bboxes': array([[ 861.,  156., 1302.,  563.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}, {'filename': 'Abyssinian_107.jpg', 'width': 500, 'height': 448, 'ann': {'bboxes': array([[ 94.,  76., 275., 271.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}, {'filename': 'Abyssinian_108.jpg', 'width': 500, 'height': 404, 'ann': {'bboxes': array([[ 50.,  14., 336., 304.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}, {'filename': 'Abyssinian_109.jpg', 'width': 282, 'height': 450, 'ann': {'bboxes': array([[ 81.,   7., 246., 146.]], dtype=float32), 'labels': array([0]), 'bboxes_ignore': array([], shape=(0, 4), dtype=float32), 'labels_ignore': array([], dtype=int64)}}]

# %% [markdown]
# ### Config를 설정하고 COCO로 Pretrained 된 모델을 Download
# * config파일은 faster rcnn resnet 50 backbone 사용.
# * Oxford Pet 데이터는 학습에 시간에 소모 되므로 학습으로 생성된 모델을 Google Drive에 저장

# %%
config_file = './mmdetection/configs/faster_rcnn/faster_rcnn_r50_fpn_1x_coco.py'
checkpoint_file = './mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth'

# %%
# !cd mmdetection; mkdir checkpoints
# !wget -O ./mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth http://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth
# Out:
# --2023-02-16 05:48:53--  http://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth
# Resolving download.openmmlab.com (download.openmmlab.com)... 8.48.85.210, 8.48.85.208, 8.48.85.212, ...
# Connecting to download.openmmlab.com (download.openmmlab.com)|8.48.85.210|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 167287506 (160M) [application/octet-stream]
# Saving to: ‘./mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth’
#
# ./mmdetection/check 100%[===================>] 159.54M  14.1MB/s    in 10s
#
# 2023-02-16 05:49:04 (15.3 MB/s) - ‘./mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth’ saved [167287506/167287506]

# %%
from mmcv import Config

cfg = Config.fromfile(config_file)
print(cfg.pretty_text)
# Out:
# model = dict(
#     type='FasterRCNN',
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=80,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))
# dataset_type = 'CocoDataset'
# data_root = 'data/coco/'
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', flip_ratio=0.5),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(1333, 800),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=2,
#     workers_per_gpu=2,
#     train=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_train2017.json',
#         img_prefix='data/coco/train2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
#         ]),
#     val=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_val2017.json',
#         img_prefix='data/coco/val2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]),
#     test=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_val2017.json',
#         img_prefix='data/coco/val2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]))
# evaluation = dict(interval=1, metric='bbox')
# optimizer = dict(type='SGD', lr=0.02, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='step',
#     warmup='linear',
#     warmup_iters=500,
#     warmup_ratio=0.001,
#     step=[8, 11])
# runner = dict(type='EpochBasedRunner', max_epochs=12)
# checkpoint_config = dict(interval=1)
# log_config = dict(interval=50, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [dict(type='NumClassCheckHook')]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]
# opencv_num_threads = 0
# mp_start_method = 'fork'
# auto_scale_lr = dict(enable=False, base_batch_size=16)

# %%
# Google Drive 접근을 위한 Mount 적용.
import os, sys
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/gdrive

# %%
# soft link로 Google Drive Directory 연결.
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# '1.4 데이터 핸들링 - 판다스 (1).ipynb'	 test_colab01.ipynb
# '1.4 데이터 핸들링 - 판다스.ipynb'	 timeseries_tf.ipynb
#  application_test.csv			 torch_basic_01_pocket.ipynb
#  application_train.csv			 torch_efficientdet.ipynb
#  attention_01.ipynb			 train_santander.csv
#  bayesian.ipynb				 ultra_workdir
#  bkup					 Untitled
# 'Colab Notebooks'			 Untitled0.ipynb
#  credit_card_balance.csv		 Untitled10.ipynb
#  download				 Untitled11.ipynb
#  dump-postgres-202202132319		 Untitled12.ipynb
#  efficientdet01.ipynb			 Untitled13.ipynb
#  esri_work_dir				 Untitled14.ipynb
#  experiencor_yolov3_001.ipynb		 Untitled15.ipynb
#  face_mask.zip				 Untitled16.ipynb
#  HomeCredit_columns_description.csv	 Untitled17.ipynb
#  installments_payments.csv		 Untitled18.ipynb
#  kaggle.json				 Untitled19.ipynb
#  keras_yolov3_001.ipynb			 Untitled1.ipynb
#  LeNet_torch.ipynb			 Untitled20.ipynb
#  LG					 Untitled2.ipynb
#  mask_work_dir				 Untitled3.ipynb
#  melanoma_jpeg.zip			 Untitled4.ipynb
#  models					 Untitled5.ipynb
# 'My Drive'				 Untitled6.ipynb
#  perfect_guide				 Untitled7.ipynb
#  PerfectGuide.zip			 Untitled8.ipynb
#  pet_work_dir				 Untitled9.ipynb
#  POS_CASH_balance.csv			 user_response.txt
#  President.ipynb			 word_cloud.ipynb
#  previous_application.csv		 yolov2_test01.ipynb
#  sales_visual.ipynb			 강의영상백업
#  sample_submission.csv			 매출분석_SQL_실습_01.sql
#  sea_depth.zip				 분석을_위한_SQL.pptx
#  seq2seq_attention_tf.ipynb		 실습자료
#  seq2seq_torch.ipynb			 온라인강의자료_1장_수정.pptx
#  session_visual.ipynb			'온라인강의자료_1장 [자동 저장].pptx'
#  SQL_강의.xlsx				 유저반응텍스트2.xlsx
#  SQL_자료				'제목 없는 프레젠테이션.gslides'
#  ssd_pytorch_01.ipynb

# %%
# Google Drive 밑에 Directory 생성. 이미 생성 되어 있을 시 오류 발생.
# !mkdir "/mydrive/pet_work_dir"
# Out:
# mkdir: cannot create directory ‘/mydrive/pet_work_dir’: File exists

# %%
# !nvidia-smi
# Out:
# Thu Feb 16 05:49:32 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from mmdet.apis import set_random_seed

# dataset에 대한 환경 파라미터 수정.
cfg.dataset_type = 'PetDataset'
cfg.data_root = '/content/data/'

# train, val, test dataset에 대한 type, data_root, ann_file, img_prefix 환경 파라미터 수정.
cfg.data.train.type = 'PetDataset'
cfg.data.train.data_root = '/content/data/'
cfg.data.train.ann_file = 'train.txt'
cfg.data.train.img_prefix = 'images'

cfg.data.val.type = 'PetDataset'
cfg.data.val.data_root = '/content/data/'
cfg.data.val.ann_file = 'val.txt'
cfg.data.val.img_prefix = 'images'

# class의 갯수 수정.
cfg.model.roi_head.bbox_head.num_classes = 37
# pretrained 모델
cfg.load_from = 'checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth'

# 학습 weight 파일로 로그를 저장하기 위한 디렉토리로 구글 Drive 설정.
cfg.work_dir = '/mydrive/pet_work_dir'

# 학습율 변경 환경 파라미터 설정.
cfg.optimizer.lr = 0.02 / 8
cfg.lr_config.warmup = None
cfg.log_config.interval = 5

cfg.runner.max_epochs = 5

# 평가 metric 설정.
cfg.evaluation.metric = 'mAP'
# 평가 metric 수행할 epoch interval 설정.
cfg.evaluation.interval = 5
# 학습 iteration시마다 모델을 저장할 epoch interval 설정.
cfg.checkpoint_config.interval = 5

# 학습 시 Batch size 설정(단일 GPU 별 Batch size로 설정됨)
cfg.data.samples_per_gpu = 4

# Set seed thus the results are more reproducible
cfg.seed = 0
set_random_seed(0, deterministic=False)
cfg.gpu_ids = range(1)
# 두번 config를 로드하면 lr_config의 policy가 사라지는 오류로 인하여 설정.
cfg.lr_config.policy='step'

# ConfigDict' object has no attribute 'device 오류 발생시 반드시 설정 필요. https://github.com/open-mmlab/mmdetection/issues/7901
cfg.device='cuda'

# We can initialize the logger for training and have a look
# at the final config used for training
print(f'Config:\n{cfg.pretty_text}')
# Out:
# Config:
# model = dict(
#     type='FasterRCNN',
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=37,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))
# dataset_type = 'PetDataset'
# data_root = '/content/data/'
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', flip_ratio=0.5),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(1333, 800),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=4,
#     workers_per_gpu=2,
#     train=dict(
#         type='PetDataset',
#         ann_file='train.txt',
#         img_prefix='images',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
#         ],
#         data_root='/content/data/'),
#     val=dict(
#         type='PetDataset',
#         ann_file='val.txt',
#         img_prefix='images',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         data_root='/content/data/'),
#     test=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_val2017.json',
#         img_prefix='data/coco/val2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]))
# evaluation = dict(interval=5, metric='mAP')
# optimizer = dict(type='SGD', lr=0.0025, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='step',
#     warmup=None,
#     warmup_iters=500,
#     warmup_ratio=0.001,
#     step=[8, 11])
# runner = dict(type='EpochBasedRunner', max_epochs=5)
# checkpoint_config = dict(interval=5)
# log_config = dict(interval=5, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [dict(type='NumClassCheckHook')]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = 'checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth'
# resume_from = None
# workflow = [('train', 1)]
# opencv_num_threads = 0
# mp_start_method = 'fork'
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# work_dir = '/mydrive/pet_work_dir'
# seed = 0
# gpu_ids = range(0, 1)
# device = 'cuda'

# %% [markdown]
# ### Train용 데이터를 생성하고 Oxford Dataset을 학습수행.
# * build_dataset()로 train config 설정에 따른 Train용 dataset 생성.
# * build_detector()로 train과 test config반영하여 model 생성.
# * train_detector()로 model 학습.

# %%
from mmdet.datasets import build_dataset
from mmdet.models import build_detector
from mmdet.apis import train_detector

# train용 Dataset 생성.
datasets = [build_dataset(cfg.data.train)]
# Out:
# <ipython-input-15-b2b3450618a1>:71: DeprecationWarning: `np.long` is a deprecated alias for `np.compat.long`. To silence this warning, use `np.compat.long` by itself. In the likely event your code does not need to work on Python 2 you can use the builtin `int` for which `np.compat.long` is itself an alias. Doing this will not modify any behaviour and is safe. When replacing `np.long`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   'labels': np.array(gt_labels, dtype=np.long),
# <ipython-input-15-b2b3450618a1>:73: DeprecationWarning: `np.long` is a deprecated alias for `np.compat.long`. To silence this warning, use `np.compat.long` by itself. In the likely event your code does not need to work on Python 2 you can use the builtin `int` for which `np.compat.long` is itself an alias. Doing this will not modify any behaviour and is safe. When replacing `np.long`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   'labels_ignore': np.array(gt_labels_ignore, dtype=np.long)
# /usr/local/lib/python3.8/dist-packages/mmdet-2.28.1-py3.8.egg/mmdet/datasets/custom.py:181: UserWarning: CustomDataset does not support filtering empty gt images.
#   warnings.warn(

# %%
datasets
# Out:
# [
#  PetDataset Train dataset with number of images 3304, and instance counts:
#  +-----------------------+-------+-------------------------+-------+-------------------------------+-------+---------------------+-------+---------------------------------+-------+
#  | category              | count | category                | count | category                      | count | category            | count | category                        | count |
#  +-----------------------+-------+-------------------------+-------+-------------------------------+-------+---------------------+-------+---------------------------------+-------+
#  | 0 [Abyssinian]        | 89    | 1 [american_bulldog]    | 90    | 2 [american_pit_bull_terrier] | 90    | 3 [basset_hound]    | 90    | 4 [beagle]                      | 90    |
#  | 5 [Bengal]            | 89    | 6 [Birman]              | 90    | 7 [Bombay]                    | 86    | 8 [boxer]           | 90    | 9 [British_Shorthair]           | 90    |
#  | 10 [chihuahua]        | 90    | 11 [Egyptian_Mau]       | 81    | 12 [english_cocker_spaniel]   | 86    | 13 [english_setter] | 90    | 14 [german_shorthaired]         | 90    |
#  | 15 [great_pyrenees]   | 90    | 16 [havanese]           | 90    | 17 [japanese_chin]            | 90    | 18 [keeshond]       | 90    | 19 [leonberger]                 | 90    |
#  | 20 [Maine_Coon]       | 90    | 21 [miniature_pinscher] | 90    | 22 [newfoundland]             | 87    | 23 [Persian]        | 90    | 24 [pomeranian]                 | 90    |
#  | 25 [pug]              | 90    | 26 [Ragdoll]            | 89    | 27 [Russian_Blue]             | 90    | 28 [saint_bernard]  | 89    | 29 [samoyed]                    | 90    |
#  | 30 [scottish_terrier] | 90    | 31 [shiba_inu]          | 90    | 32 [Siamese]                  | 89    | 33 [Sphynx]         | 90    | 34 [staffordshire_bull_terrier] | 90    |
#  |                       |       |                         |       |                               |       |                     |       |                                 |       |
#  | 35 [wheaten_terrier]  | 90    | 36 [yorkshire_terrier]  | 90    |                               |       |                     |       |                                 |       |
#  +-----------------------+-------+-------------------------+-------+-------------------------------+-------+---------------------+-------+---------------------------------+-------+]

# %%
# %cd mmdetection

model = build_detector(cfg.model, train_cfg=cfg.get('train_cfg'), test_cfg=cfg.get('test_cfg'))
model.CLASSES = datasets[0].CLASSES

mmcv.mkdir_or_exist(osp.abspath(cfg.work_dir))
# epochs는 config의 runner 파라미터로 지정됨. 기본 12회
train_detector(model, datasets, cfg, distributed=False, validate=True)

# %%
|!ls -lia /content/data/images/english_cocker_spaniel*

# %% [markdown]
# ### 학습된 model을 이용하여 inference 수행.
# * 현재 memory에서 학습된 model 및 checkpoint 기록된 model을 loading하여 inference 수행.

# %%
from mmdet.apis import inference_detector, init_detector, show_result_pyplot

# BGR Image 사용
img = cv2.imread('/content/data/images/Abyssinian_88.jpg')

model.cfg = cfg

result = inference_detector(model, img)
show_result_pyplot(model, img, result, score_thr=0.3)

# %%
result

# %%
# 아래는 오류를 발생시킵니다. 현재 Customized학습된 모델의 inference시 image file로 인자가 주어졌을때 inference 오류 발생.
img_path = '/content/data/images/Abyssinian_88.jpg'

model.cfg = cfg

result = inference_detector(model, img_path)
show_result_pyplot(model, img, result, score_thr=0.3)

# %% [markdown]
# ### Checkpoint 저장된 model 파일을 로딩하고 이를 이용하여 Inference 수행.

# %%
from mmdet.apis import show_result_pyplot

checkpoint_file = '/mydrive/pet_work_dir/epoch_5.pth'

# checkpoint 저장된 model 파일을 이용하여 모델을 생성, 이때 Config는 위에서 update된 config 사용.
model_ckpt = init_detector(cfg, checkpoint_file, device='cuda:0')
# BGR Image 사용
img = cv2.imread('/content/data/images/Abyssinian_88.jpg')
#model_ckpt.cfg = cfg

result = inference_detector(model_ckpt, img)
show_result_pyplot(model_ckpt, img, result, score_thr=0.3)

# %% [markdown]
# ### 여러개의 image들을 Inference 수행.
# * inference_detector(model, imgs) 에서 인자 imgs는 단일 이미지일 경우 string/array, 여러개의 이미지일 경우 list(string/array)를 입력
# * show_result_pyplot(model_ckpt, img, result, score_thr=0.3)는 여러개의 이미지를 한번에 나타내기 어려우므로 별도의 시각화 함수 get_detected_img()를 이용

# %%
val_df

# %%
val_df['img_path'] = '/content/data/images/' + val_df['img_name'] + '.jpg'
val_df.head()

# %%
val_df[val_df['img_path'].str.contains('Abyssinian')]['img_path'].values

# %%
val_paths = val_df[val_df['img_path'].str.contains('Abyssinian')]['img_path'].values
val_imgs = [cv2.imread(x) for x in val_paths]

# %%
type(val_imgs), len(val_imgs), val_imgs[0].shape

# %%
# 반환된 results는 개별 원소로 list를 가지는 list임.
results = inference_detector(model_ckpt, val_imgs)

# %%
len(results), len(results[0]), results

# %%
PET_CLASSES = pet_df['class_name'].unique().tolist()
labels_to_names_seq = {i:k for i, k in enumerate(PET_CLASSES)}

# model과 원본 이미지 array, filtering할 기준 class confidence score를 인자로 가지는 inference 시각화용 함수 생성.
def get_detected_img(model, img_array,  score_threshold=0.3, is_print=True):
  # 인자로 들어온 image_array를 복사.
  draw_img = img_array.copy()
  bbox_color=(0, 255, 0)
  text_color=(0, 0, 255)

  # model과 image array를 입력 인자로 inference detection 수행하고 결과를 results로 받음.
  # results는 80개의 2차원 array(shape=(오브젝트갯수, 5))를 가지는 list.
  results = inference_detector(model, img_array)

  # 80개의 array원소를 가지는 results 리스트를 loop를 돌면서 개별 2차원 array들을 추출하고 이를 기반으로 이미지 시각화
  # results 리스트의 위치 index가 바로 COCO 매핑된 Class id. 여기서는 result_ind가 class id
  # 개별 2차원 array에 오브젝트별 좌표와 class confidence score 값을 가짐.
  for result_ind, result in enumerate(results):
    # 개별 2차원 array의 row size가 0 이면 해당 Class id로 값이 없으므로 다음 loop로 진행.
    if len(result) == 0:
      continue

    # 2차원 array에서 5번째 컬럼에 해당하는 값이 score threshold이며 이 값이 함수 인자로 들어온 score_threshold 보다 낮은 경우는 제외.
    result_filtered = result[np.where(result[:, 4] > score_threshold)]

    # 해당 클래스 별로 Detect된 여러개의 오브젝트 정보가 2차원 array에 담겨 있으며, 이 2차원 array를 row수만큼 iteration해서 개별 오브젝트의 좌표값 추출.
    for i in range(len(result_filtered)):
      # 좌상단, 우하단 좌표 추출.
      left = int(result_filtered[i, 0])
      top = int(result_filtered[i, 1])
      right = int(result_filtered[i, 2])
      bottom = int(result_filtered[i, 3])
      caption = "{}: {:.4f}".format(labels_to_names_seq[result_ind], result_filtered[i, 4])
      cv2.rectangle(draw_img, (left, top), (right, bottom), color=bbox_color, thickness=2)
      cv2.putText(draw_img, caption, (int(left), int(top - 7)), cv2.FONT_HERSHEY_SIMPLEX, 0.6, text_color, 1)
      if is_print:
        print(caption)

  return draw_img

# %%
import matplotlib.pyplot as plt

img_arr = cv2.imread('/content/data/images/Abyssinian_88.jpg')
detected_img = get_detected_img(model, img_arr,  score_threshold=0.3, is_print=True)
# detect 입력된 이미지는 bgr임. 이를 최종 출력시 rgb로 변환
detected_img = cv2.cvtColor(detected_img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(12, 12))
plt.imshow(detected_img)

# %%
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

def show_detected_images(model, img_arrays, ncols=5):
    figure, axs = plt.subplots(figsize=(22, 6), nrows=1, ncols=ncols)
    for i in range(ncols):
      detected_img = get_detected_img(model, img_arrays[i],  score_threshold=0.5, is_print=True)
      detected_img = cv2.cvtColor(detected_img, cv2.COLOR_BGR2RGB)
      #detected_img = cv2.resize(detected_img, (328, 328))
      axs[i].imshow(detected_img)


show_detected_images(model_ckpt, val_imgs[:5], ncols=5)
show_detected_images(model_ckpt, val_imgs[5:10], ncols=5)

# %%
val_paths = val_df[val_df['img_path'].str.contains('Persian')]['img_path'].values
val_imgs = [cv2.imread(x) for x in val_paths]

show_detected_images(model_ckpt, val_imgs[:5], ncols=5)
show_detected_images(model_ckpt, val_imgs[5:10], ncols=5)
